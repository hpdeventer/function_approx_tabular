# %%
# Importing necessary modules
import os
import time
import numpy as np
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.metrics import r2_score, mean_squared_error
from model_data_definitions import *
from concurrent.futures import ThreadPoolExecutor, ProcessPoolExecutor

# Function to generate cross validation dataset
def generate_cross_validation_dataset(data, num_folds):
    X, y = data.drop('target', axis=1).values, data['target'].values
    
    dataset_list = []
    kf = KFold(n_splits=num_folds)
    fold = 0

    # Splitting data into training and testing set for each fold in the cross-validation 
    for train_index, test_index in kf.split(X):
        fold += 1
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]
        
        dataset_list.append((X_train, y_train, X_test, y_test , fold))
    
    return dataset_list

# Function to train and evaluate model
def train_evaluate_model(model_tuple, fold_data, epoch_number, dataset_name,num_folds):
    
    model, name = model_tuple
    X_train, y_train, X_test, y_test , fold = fold_data
    
    # Training the model 
    history = model.fit(X_train,
                        y_train,
                        epochs=epoch_number,
                        verbose=0,
                        validation_data=(X_test,y_test))

     # Evaluating the trained model on test data 
    loss = model.evaluate(X_test,y_test)

     # Making predictions on the test data 
    predictions = model.predict(X_test)
    
     # Calculate metrics 
    r_squared_value=r2_score(y_true=y_test,y_pred=predictions)
    test_error=mean_squared_error(y_true=y_test,y_pred=predictions)

    results = {
        'model': name,
        'fold': fold,
        'train_history': history.history['loss'],
        'val_history': history.history['val_loss'],
        'loss': loss,
        'r_squared_value': r_squared_value,
        'test_error': test_error}

    # Save results to numpy file
    if not os.path.exists('aggregate_results'):
        os.makedirs('aggregate_results')

    np.save(f'aggregate_results/{dataset_name}-{name}-fold-{fold}-of-{num_folds}.npy', results)

# Function to evaluate models in parallel
def evaluate_models_parallel(fold_data, dataset_name, epoch_number,num_folds):
    
    models = initialize_all_models(fold_data[0].shape[1], seed_val=fold_data[4])
    compile_models(models)

     # Training and evaluating all models in parallel using ThreadPoolExecutor 
    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(train_evaluate_model, model, fold_data, epoch_number, dataset_name,num_folds): model for model in models}
        for future in futures:
            future.result()  # Just to make sure all tasks are finished

# Function to evaluate all folds in parallel
def evaluate_all_folds_parallel(kfold_datasets, dataset_name, epoch_number,num_folds):
    
     # Evaluating all folds in parallel using ThreadPoolExecutor 
    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(evaluate_models_parallel, fold_data, dataset_name, epoch_number,num_folds): fold_data for fold_data in kfold_datasets}
        for future in futures:
            future.result()  # Just to make sure all tasks are finished

# New function to retrieve all datasets and their names and feed it to relevant functions with a for loop.
def retrieve_datasets_and_run_evaluations(num_folds=5, epoch_number=100):
    # Fetching data 
    filtered_datasets_metadata, datasets = fetch_return_filtered_pmlb_data_sets()

    for dataset, row in zip(datasets, filtered_datasets_metadata.iterrows()):
        dataset_name = row[1]['dataset']
        kfold_datasets = generate_cross_validation_dataset(dataset, num_folds)
        evaluate_all_folds_parallel(kfold_datasets, dataset_name, epoch_number,num_folds)

# %%
filtered_datasets_metadata, datasets = fetch_return_filtered_pmlb_data_sets()
filtered_datasets_metadata
# Out:
#                            dataset  n_instances  n_features  \
# 0                         1027_ESL          488           4
# 2                         1029_LEV         1000           4
# 3                         1030_ERA         1000           4
# 5             1096_FacultySalaries           50           4
# 13                    192_vineyard           52           2
# 23                     228_elusage           55           2
# 25                 230_machine_cpu          209           6
# 29         485_analcatdata_vehicle           48           4
# 32                      519_vinnie          380           2
# 34         523_analcatdata_neavote          100           2
# 36                      529_pollen         3848           4
# 40          556_analcatdata_apnea2          475           3
# 41          557_analcatdata_apnea1          475           3
# 48                579_fri_c0_250_5          250           5
# 60                594_fri_c2_100_5          100           5
# 62                596_fri_c2_250_5          250           5
# 63                597_fri_c2_500_5          500           5
# 65               599_fri_c2_1000_5         1000           5
# 66                601_fri_c1_250_5          250           5
# 74               609_fri_c0_1000_5         1000           5
# 75                611_fri_c3_100_5          100           5
# 76               612_fri_c1_1000_5         1000           5
# 77                613_fri_c3_250_5          250           5
# 80                617_fri_c3_500_5          500           5
# 86                624_fri_c0_100_5          100           5
# 89               628_fri_c3_1000_5         1000           5
# 90                631_fri_c1_500_5          500           5
# 102               649_fri_c0_500_5          500           5
# 107               656_fri_c1_100_5          100           5
# 111                   663_rabe_266          120           2
# 112            665_sleuth_case2002          147           6
# 114  678_visualizing_environmental          111           3
# 115              687_sleuth_ex1605           62           5
# 116         690_visualizing_galaxy          323           4
# 118            706_sleuth_case1202           93           6
# 119            712_chscase_geyser1          222           2
# 155                         banana         5300           2
# 270                        titanic         2201           3
#
#      n_binary_features  n_categorical_features  n_continuous_features  \
# 0                    0                       0                      4
# 2                    0                       0                      4
# 3                    0                       0                      4
# 5                    0                       0                      4
# 13                   0                       0                      2
# 23                   0                       0                      2
# 25                   0                       0                      6
# 29                   0                       0                      4
# 32                   0                       0                      2
# 34                   0                       0                      2
# 36                   0                       0                      4
# 40                   0                       0                      3
# 41                   0                       0                      3
# 48                   0                       0                      5
# 60                   0                       0                      5
# 62                   0                       0                      5
# 63                   0                       0                      5
# 65                   0                       0                      5
# 66                   0                       0                      5
# 74                   0                       0                      5
# 75                   0                       0                      5
# 76                   0                       0                      5
# 77                   0                       0                      5
# 80                   0                       0                      5
# 86                   0                       0                      5
# 89                   0                       0                      5
# 90                   0                       0                      5
# 102                  0                       0                      5
# 107                  0                       0                      5
# 111                  0                       0                      2
# 112                  0                       0                      6
# 114                  0                       0                      3
# 115                  0                       0                      5
# 116                  0                       0                      4
# 118                  0                       0                      6
# 119                  0                       0                      2
# 155                  0                       0                      2
# 270                  0                       0                      3
#
#     endpoint_type  n_classes  imbalance        task
# 0      continuous        9.0   0.099363  regression
# 2      continuous        5.0   0.111245  regression
# 3      continuous        9.0   0.031251  regression
# 5      continuous       39.0   0.004063  regression
# 13     continuous       19.0   0.040475  regression
# 23     continuous       52.0   0.000953  regression
# 25     continuous      116.0   0.004906  regression
# 29     continuous       47.0   0.000434  regression
# 32     continuous       16.0   0.030146  regression
# 34     continuous        8.0   0.136914  regression
# 36     continuous     3784.0   0.000004  regression
# 40     continuous      178.0   0.272393  regression
# 41     continuous      164.0   0.325260  regression
# 48     continuous      250.0   0.000000  regression
# 60     continuous      100.0   0.000000  regression
# 62     continuous      250.0   0.000000  regression
# 63     continuous      500.0   0.000000  regression
# 65     continuous     1000.0   0.000000  regression
# 66     continuous      250.0   0.000000  regression
# 74     continuous     1000.0   0.000000  regression
# 75     continuous      100.0   0.000000  regression
# 76     continuous     1000.0   0.000000  regression
# 77     continuous      250.0   0.000000  regression
# 80     continuous      500.0   0.000000  regression
# 86     continuous      100.0   0.000000  regression
# 89     continuous     1000.0   0.000000  regression
# 90     continuous      500.0   0.000000  regression
# 102    continuous      500.0   0.000000  regression
# 107    continuous      100.0   0.000000  regression
# 111    continuous       96.0   0.001825  regression
# 112    continuous       19.0   0.096020  regression
# 114    continuous       28.0   0.019608  regression
# 115    continuous       41.0   0.006465  regression
# 116    continuous      208.0   0.001246  regression
# 118    continuous       79.0   0.001583  regression
# 119    continuous       50.0   0.012844  regression
# 155    continuous        2.0   0.010691  regression
# 270    continuous        2.0   0.125266  regression

# %%
# Call the new function 
start_time = time.time()
retrieve_datasets_and_run_evaluations(num_folds=4, epoch_number=2)
end_time = time.time()
elapsed_time = end_time - start_time
print(f"The experiment took {elapsed_time} seconds to complete.")

# %%
# Importing necessary modules
import os
import time
import numpy as np
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.metrics import r2_score, mean_squared_error
from model_data_definitions import *
from concurrent.futures import ThreadPoolExecutor, ProcessPoolExecutor

# Function to generate cross validation dataset
def generate_cross_validation_dataset(data, num_folds):
    X, y = data.drop('target', axis=1).values, data['target'].values
    
    dataset_list = []
    kf = KFold(n_splits=num_folds)
    fold = 0

    # Splitting data into training and testing set for each fold in the cross-validation 
    for train_index, test_index in kf.split(X):
        fold += 1
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]
        
        X_train, X_test = preprocess_data(X_train, X_test)
        y_train, y_test = preprocess_target_values(y_train, y_test)
        
        dataset_list.append((X_train, y_train, X_test, y_test , fold))
    
    return dataset_list

# Function to train and evaluate model
def train_evaluate_model(model_tuple, fold_data, epoch_number, dataset_name,num_folds):
    
    model, name = model_tuple
    X_train, y_train, X_test, y_test , fold = fold_data
    
    # Training the model 
    history = model.fit(X_train,
                        y_train,
                        epochs=epoch_number,
                        verbose=0,
                        validation_data=(X_test,y_test))

     # Evaluating the trained model on test data 
    loss = model.evaluate(X_test,y_test)

     # Making predictions on the test data 
    predictions = model.predict(X_test)
    
     # Calculate metrics 
    r_squared_value=r2_score(y_true=y_test,y_pred=predictions)
    test_error=mean_squared_error(y_true=y_test,y_pred=predictions)

    results = {
        'model': name,
        'fold': fold,
        'train_history': history.history['loss'],
        'val_history': history.history['val_loss'],
        'loss': loss,
        'r_squared_value': r_squared_value,
        'test_error': test_error}

    # Save results to numpy file
    if not os.path.exists('aggregate_results'):
        os.makedirs('aggregate_results')

    np.save(f'aggregate_results/{dataset_name}-{name}-epochs-{epoch_number}-fold-{fold}-of-{num_folds}.npy', results)

# Function to evaluate models in parallel
def evaluate_models_parallel(fold_data, dataset_name, epoch_number,num_folds):
    
    models = initialize_all_models(fold_data[0].shape[1], seed_val=fold_data[4])
    compile_models(models)

     # Training and evaluating all models in parallel using ThreadPoolExecutor 
    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(train_evaluate_model, 
                                   model, 
                                   fold_data, 
                                   epoch_number, 
                                   dataset_name,
                                   num_folds): model for model in models}
        for future in futures:
            future.result()  # Just to make sure all tasks are finished

# Function to evaluate all folds in parallel
def evaluate_all_folds_parallel(kfold_datasets, dataset_name, epoch_number,num_folds):
    
     # Evaluating all folds in parallel using ThreadPoolExecutor 
    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(evaluate_models_parallel, 
                                   fold_data, 
                                   dataset_name, 
                                   epoch_number,
                                   num_folds): fold_data for fold_data in kfold_datasets}
        for future in futures:
            future.result()  # Just to make sure all tasks are finished

# New function to retrieve all datasets and their names and feed it to relevant functions with a for loop.
def retrieve_datasets_and_run_evaluations(num_folds=5, epoch_number=100):
    # Fetching data 
    filtered_datasets_metadata, datasets = fetch_return_filtered_pmlb_data_sets()

    for dataset, row in zip(datasets, filtered_datasets_metadata.iterrows()):
        dataset_name = row[1]['dataset']
        kfold_datasets = generate_cross_validation_dataset(dataset, num_folds)
        evaluate_all_folds_parallel(kfold_datasets, dataset_name, epoch_number,num_folds)

# %%
filtered_datasets_metadata, datasets = fetch_return_filtered_pmlb_data_sets()
filtered_datasets_metadata
# Out:
#                            dataset  n_instances  n_features  \
# 0                         1027_ESL          488           4
# 2                         1029_LEV         1000           4
# 3                         1030_ERA         1000           4
# 5             1096_FacultySalaries           50           4
# 13                    192_vineyard           52           2
# 23                     228_elusage           55           2
# 25                 230_machine_cpu          209           6
# 29         485_analcatdata_vehicle           48           4
# 32                      519_vinnie          380           2
# 34         523_analcatdata_neavote          100           2
# 36                      529_pollen         3848           4
# 40          556_analcatdata_apnea2          475           3
# 41          557_analcatdata_apnea1          475           3
# 48                579_fri_c0_250_5          250           5
# 60                594_fri_c2_100_5          100           5
# 62                596_fri_c2_250_5          250           5
# 63                597_fri_c2_500_5          500           5
# 65               599_fri_c2_1000_5         1000           5
# 66                601_fri_c1_250_5          250           5
# 74               609_fri_c0_1000_5         1000           5
# 75                611_fri_c3_100_5          100           5
# 76               612_fri_c1_1000_5         1000           5
# 77                613_fri_c3_250_5          250           5
# 80                617_fri_c3_500_5          500           5
# 86                624_fri_c0_100_5          100           5
# 89               628_fri_c3_1000_5         1000           5
# 90                631_fri_c1_500_5          500           5
# 102               649_fri_c0_500_5          500           5
# 107               656_fri_c1_100_5          100           5
# 111                   663_rabe_266          120           2
# 112            665_sleuth_case2002          147           6
# 114  678_visualizing_environmental          111           3
# 115              687_sleuth_ex1605           62           5
# 116         690_visualizing_galaxy          323           4
# 118            706_sleuth_case1202           93           6
# 119            712_chscase_geyser1          222           2
# 155                         banana         5300           2
# 270                        titanic         2201           3
#
#      n_binary_features  n_categorical_features  n_continuous_features  \
# 0                    0                       0                      4
# 2                    0                       0                      4
# 3                    0                       0                      4
# 5                    0                       0                      4
# 13                   0                       0                      2
# 23                   0                       0                      2
# 25                   0                       0                      6
# 29                   0                       0                      4
# 32                   0                       0                      2
# 34                   0                       0                      2
# 36                   0                       0                      4
# 40                   0                       0                      3
# 41                   0                       0                      3
# 48                   0                       0                      5
# 60                   0                       0                      5
# 62                   0                       0                      5
# 63                   0                       0                      5
# 65                   0                       0                      5
# 66                   0                       0                      5
# 74                   0                       0                      5
# 75                   0                       0                      5
# 76                   0                       0                      5
# 77                   0                       0                      5
# 80                   0                       0                      5
# 86                   0                       0                      5
# 89                   0                       0                      5
# 90                   0                       0                      5
# 102                  0                       0                      5
# 107                  0                       0                      5
# 111                  0                       0                      2
# 112                  0                       0                      6
# 114                  0                       0                      3
# 115                  0                       0                      5
# 116                  0                       0                      4
# 118                  0                       0                      6
# 119                  0                       0                      2
# 155                  0                       0                      2
# 270                  0                       0                      3
#
#     endpoint_type  n_classes  imbalance        task
# 0      continuous        9.0   0.099363  regression
# 2      continuous        5.0   0.111245  regression
# 3      continuous        9.0   0.031251  regression
# 5      continuous       39.0   0.004063  regression
# 13     continuous       19.0   0.040475  regression
# 23     continuous       52.0   0.000953  regression
# 25     continuous      116.0   0.004906  regression
# 29     continuous       47.0   0.000434  regression
# 32     continuous       16.0   0.030146  regression
# 34     continuous        8.0   0.136914  regression
# 36     continuous     3784.0   0.000004  regression
# 40     continuous      178.0   0.272393  regression
# 41     continuous      164.0   0.325260  regression
# 48     continuous      250.0   0.000000  regression
# 60     continuous      100.0   0.000000  regression
# 62     continuous      250.0   0.000000  regression
# 63     continuous      500.0   0.000000  regression
# 65     continuous     1000.0   0.000000  regression
# 66     continuous      250.0   0.000000  regression
# 74     continuous     1000.0   0.000000  regression
# 75     continuous      100.0   0.000000  regression
# 76     continuous     1000.0   0.000000  regression
# 77     continuous      250.0   0.000000  regression
# 80     continuous      500.0   0.000000  regression
# 86     continuous      100.0   0.000000  regression
# 89     continuous     1000.0   0.000000  regression
# 90     continuous      500.0   0.000000  regression
# 102    continuous      500.0   0.000000  regression
# 107    continuous      100.0   0.000000  regression
# 111    continuous       96.0   0.001825  regression
# 112    continuous       19.0   0.096020  regression
# 114    continuous       28.0   0.019608  regression
# 115    continuous       41.0   0.006465  regression
# 116    continuous      208.0   0.001246  regression
# 118    continuous       79.0   0.001583  regression
# 119    continuous       50.0   0.012844  regression
# 155    continuous        2.0   0.010691  regression
# 270    continuous        2.0   0.125266  regression

# %%
# Call the new function 
start_time = time.time()
retrieve_datasets_and_run_evaluations(num_folds=2, epoch_number=1)
end_time = time.time()
elapsed_time = end_time - start_time
print(f"The experiment took {elapsed_time} seconds to complete.")
# Out:
# 8/8 [==============================] - 0s 21ms/step - loss: 5.1561
# 8/8 [==============================] - 0s 30ms/step - loss: 4.4140
# 8/8 [==============================] - 1s 25ms/step
# 8/8 [==============================] - 0s 25ms/step - loss: 5.2452
# 8/8 [==============================] - 0s 12ms/step - loss: 5.1301
# 8/8 [==============================] - 0s 14ms/step - loss: 5.1392
# 8/8 [==============================] - 0s 6ms/step - loss: 5.1731
# 8/8 [==============================] - 0s 20ms/step
# 8/8 [==============================] - 0s 13ms/step - loss: 5.1736
# 8/8 [==============================] - 0s 15ms/step - loss: 5.1301
# 8/8 [==============================] - 0s 25ms/step - loss: 4.4994
# 8/8 [==============================] - 0s 16ms/step - loss: 5.1718
# 8/8 [==============================] - 1s 27ms/step
# 8/8 [==============================] - 0s 19ms/step - loss: 5.2289
# 8/8 [==============================] - 0s 19ms/step - loss: 5.2289
# 8/8 [==============================] - 0s 16ms/step - loss: 5.2767
# 8/8 [==============================] - 1s 19ms/stepss: 4.99
# 8/8 [==============================] - 1s 22ms/stepss: 4.
# 8/8 [==============================] - 0s 28ms/step - loss: 5.2747
# 8/8 [==============================] - 1s 27ms/stepss: 5.29
# 8/8 [==============================] - 1s 20ms/stepss:
# 8/8 [==============================] - 1s 20ms/stepss: 5.27
# 8/8 [==============================] - 0s 39ms/step - loss: 5.2718
# 8/8 [==============================] - 0s 32ms/step - loss: 5.2668
# 8/8 [==============================] - 1s 23ms/step
# 8/8 [==============================] - 1s 35ms/step
# 8/8 [==============================] - 1s 12ms/step
# 8/8 [==============================] - 1s 14ms/step
# 8/8 [==============================] - 1s 14ms/step
# 8/8 [==============================] - 1s 12ms/step
# 8/8 [==============================] - 1s 12ms/step
# 8/8 [==============================] - 1s 11ms/step
# 8/8 [==============================] - 0s 5ms/step - loss: 5.0428
# 8/8 [==============================] - 0s 3ms/step - loss: 4.5028
# 8/8 [==============================] - 1s 4ms/step
# 8/8 [==============================] - 0s 3ms/step
# 8/8 [==============================] - 0s 10ms/step - loss: 5.1155
# 8/8 [==============================] - 0s 22ms/step - loss: 5.1088
# 8/8 [==============================] - 0s 18ms/step - loss: 5.1191
# 8/8 [==============================] - 0s 10ms/step - loss: 5.0783
# 8/8 [==============================] - 0s 21ms/step - loss: 5.0972
# 8/8 [==============================] - 0s 20ms/step - loss: 5.2497
# 8/8 [==============================] - 0s 17ms/step - loss: 5.2121
# 8/8 [==============================] - 0s 19ms/step - loss: 5.1891
# 8/8 [==============================] - 0s 16ms/step - loss: 5.2675
# 8/8 [==============================] - 3s 4ms/step
# 8/8 [==============================] - 2s 5ms/step
# 8/8 [==============================] - 2s 5ms/step
# 8/8 [==============================] - 2s 5ms/steposs: 4.911
# 8/8 [==============================] - 2s 4ms/step
# 8/8 [==============================] - 0s 6ms/step - loss: 5.1971
# 8/8 [==============================] - 2s 6ms/step
# 8/8 [==============================] - 2s 4ms/step
# 8/8 [==============================] - 2s 4ms/step
# 8/8 [==============================] - 1s 3ms/step
# 8/8 [==============================] - 0s 3ms/step
# 8/8 [==============================] - 0s 6ms/step - loss: 4.9112
# 8/8 [==============================] - 0s 7ms/step - loss: 5.0349
# 8/8 [==============================] - 0s 7ms/step - loss: 4.9705
# 8/8 [==============================] - 0s 6ms/step - loss: 4.9355
# 8/8 [==============================] - 0s 6ms/step - loss: 5.0227
# 8/8 [==============================] - 0s 6ms/step - loss: 5.0523
# 8/8 [==============================] - 0s 6ms/step - loss: 4.8551
# 8/8 [==============================] - 0s 7ms/step - loss: 4.9621
# 8/8 [==============================] - 0s 9ms/step - loss: 5.0415
# 8/8 [==============================] - 0s 6ms/step - loss: 4.9391
# 2/2 [==============================] - 1s 28ms/step
# 2/2 [==============================] - 1s 24ms/step
# 2/2 [==============================] - 1s 43ms/step
# 2/2 [==============================] - 1s 16ms/step
# 2/2 [==============================] - 1s 20ms/step
# 2/2 [==============================] - 1s 107ms/step
# 2/2 [==============================] - 1s 85ms/step
# 2/2 [==============================] - 1s 29ms/step
# 2/2 [==============================] - 0s 23ms/step - loss: 5.7768
# 2/2 [==============================] - 0s 11ms/step - loss: 5.1466
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 24ms/step - loss: 5.7822
# 2/2 [==============================] - 0s 38ms/step - loss: 5.7652
# 2/2 [==============================] - 0s 26ms/step - loss: 5.3378
# 2/2 [==============================] - 0s 43ms/step - loss: 5.3080
# 2/2 [==============================] - 0s 36ms/step - loss: 5.8063
# 2/2 [==============================] - 0s 29ms/step - loss: 5.3498
# 2/2 [==============================] - 0s 14ms/step - loss: 5.7484
# 2/2 [==============================] - 0s 28ms/step - loss: 5.2879
# 2/2 [==============================] - 0s 45ms/step - loss: 5.3182
# 2/2 [==============================] - 0s 39ms/step - loss: 5.7554
# 2/2 [==============================] - 2s 10ms/step
# 2/2 [==============================] - 2s 11ms/step
# 2/2 [==============================] - 2s 6ms/step
# 2/2 [==============================] - 2s 18ms/step
# 2/2 [==============================] - 2s 16ms/step
# 2/2 [==============================] - 2s 14ms/step
# 2/2 [==============================] - 2s 10ms/step
# 2/2 [==============================] - 2s 20ms/step
# 2/2 [==============================] - 2s 8ms/step
# 2/2 [==============================] - 2s 4ms/step
# 2/2 [==============================] - 0s 82ms/step - loss: 5.7249
# 2/2 [==============================] - 0s 29ms/step - loss: 5.7008
# 2/2 [==============================] - 0s 13ms/step - loss: 5.2313
# 2/2 [==============================] - 0s 18ms/step - loss: 5.7858
# 2/2 [==============================] - 0s 12ms/step - loss: 5.2812
# 2/2 [==============================] - 0s 16ms/step - loss: 5.2541
# 2/2 [==============================] - 0s 8ms/step - loss: 5.7857
# 2/2 [==============================] - 0s 11ms/step - loss: 5.2574
# 2/2 [==============================] - 0s 13ms/step - loss: 5.8307
# 2/2 [==============================] - 0s 12ms/step - loss: 5.3222
# 2/2 [==============================] - 2s 3ms/step
# 2/2 [==============================] - 2s 11ms/step
# 2/2 [==============================] - 2s 11ms/step
# 2/2 [==============================] - 2s 5ms/step
# 2/2 [==============================] - 2s 6ms/step
# 2/2 [==============================] - 2s 6ms/step
# 2/2 [==============================] - 2s 6ms/step
# 2/2 [==============================] - 2s 3ms/step
# 2/2 [==============================] - 2s 3ms/step
# 2/2 [==============================] - 2s 4ms/step
# 2/2 [==============================] - 0s 3ms/step - loss: 5.7659
# 2/2 [==============================] - 0s 3ms/step
# 61/61 [==============================] - 1s 17ms/step - loss: 2.6150
# 61/61 [==============================] - 1s 19ms/step - loss: 2.5238
# 61/61 [==============================] - 2s 29ms/step - loss: 1.8315
# 61/61 [==============================] - 2s 28ms/step - loss: 1.8470
# 61/61 [==============================] - 2s 26ms/stepss: 2.445
# 61/61 [==============================] - 1s 23ms/step - loss: 2.4774
# 61/61 [==============================] - 2s 28ms/step - loss: 2.4999
# 61/61 [==============================] - 2s 31ms/stepss: 2.46
# 61/61 [==============================] - 2s 25ms/step - loss: 2.4538
# 61/61 [==============================] - 2s 29ms/step - loss: 2.4700
# 61/61 [==============================] - 2s 30ms/step - loss: 2.4943
# 61/61 [==============================] - 2s 33ms/step - loss: 2.4539
# 61/61 [==============================] - 2s 31ms/step - loss: 2.4479
# 61/61 [==============================] - 2s 31ms/step - loss: 2.4919
# 61/61 [==============================] - 2s 29ms/step - loss: 2.4318
# 61/61 [==============================] - 2s 36ms/step - loss: 2.4999
# 61/61 [==============================] - 2s 26ms/step - loss: 2.4431
# 61/61 [==============================] - 2s 36ms/step - loss: 2.4228
# 61/61 [==============================] - 2s 22ms/step
# 61/61 [==============================] - 2s 18ms/step
# 61/61 [==============================] - 2s 14ms/step
# 61/61 [==============================] - 2s 17ms/step
# 61/61 [==============================] - 2s 18ms/step
# 61/61 [==============================] - 1s 13ms/step
# 61/61 [==============================] - 2s 13ms/step
# 61/61 [==============================] - 2s 15ms/step
# 61/61 [==============================] - 1s 13ms/step
# 61/61 [==============================] - 2s 15ms/step
# 61/61 [==============================] - 1s 14ms/step
# 61/61 [==============================] - 2s 17ms/step
# 61/61 [==============================] - 1s 13ms/step
# 61/61 [==============================] - 1s 14ms/step
# 61/61 [==============================] - 0s 5ms/step - loss: 1.8700
# 61/61 [==============================] - 0s 5ms/step - loss: 2.1294
# 61/61 [==============================] - 1s 7ms/step
# 61/61 [==============================] - 1s 7ms/step
# 61/61 [==============================] - 0s 7ms/step - loss: 2.3981
# ...
# 4/4 [==============================] - 0s 13ms/step - loss: 0.8546
# 4/4 [==============================] - 0s 15ms/step - loss: 0.7999
# 4/4 [==============================] - 0s 13ms/step - loss: 0.8717
# 4/4 [==============================] - 0s 12ms/step - loss: 0.8467
# 4/4 [==============================] - 0s 24ms/step - loss: 0.7933
# 4/4 [==============================] - 0s 17ms/step - loss: 0.8089
# 4/4 [==============================] - 0s 16ms/step - loss: 0.7957
# 4/4 [==============================] - 0s 16ms/step - loss: 0.8514
# 4/4 [==============================] - 0s 14ms/step - loss: 0.8580
# 4/4 [==============================] - 2s 4ms/step
# 4/4 [==============================] - 2s 4ms/step
# 4/4 [==============================] - 2s 5ms/step
# 4/4 [==============================] - 2s 3ms/step
# 4/4 [==============================] - 2s 4ms/step
# 4/4 [==============================] - 2s 6ms/step
# 4/4 [==============================] - 2s 6ms/step
# 4/4 [==============================] - 2s 3ms/step
# 4/4 [==============================] - 2s 5ms/step
# 4/4 [==============================] - 0s 11ms/step - loss: 0.8068
# 4/4 [==============================] - 0s 10ms/step - loss: 0.7994
# 4/4 [==============================] - 0s 6ms/step - loss: 0.8545
# 4/4 [==============================] - 0s 7ms/step - loss: 0.8478
# 4/4 [==============================] - 0s 7ms/step - loss: 0.7945
# 4/4 [==============================] - 0s 6ms/step - loss: 0.8538
# 4/4 [==============================] - 0s 11ms/step - loss: 0.8520
# 4/4 [==============================] - 0s 12ms/step - loss: 0.8528
# 4/4 [==============================] - 0s 8ms/step - loss: 0.7902
# 4/4 [==============================] - 0s 6ms/step - loss: 0.7682
# 4/4 [==============================] - 2s 2ms/step
# 4/4 [==============================] - 2s 3ms/step
# 4/4 [==============================] - 2s 8ms/step
# 4/4 [==============================] - 2s 7ms/step
# 4/4 [==============================] - 2s 4ms/step
# 4/4 [==============================] - 2s 3ms/step
# 4/4 [==============================] - 2s 4ms/step
# 4/4 [==============================] - 2s 5ms/step
# 4/4 [==============================] - 2s 5ms/step
# 4/4 [==============================] - 2s 5ms/step
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7893
# 4/4 [==============================] - 0s 2ms/step
# 8/8 [==============================] - 0s 13ms/step - loss: 1.0903
# 8/8 [==============================] - 0s 15ms/step - loss: 1.0044
# 8/8 [==============================] - 0s 9ms/step - loss: 0.7805
# 8/8 [==============================] - 0s 8ms/step
# 8/8 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 12ms/step - loss: 0.7510
# 8/8 [==============================] - 0s 10ms/step - loss: 0.8417
# 8/8 [==============================] - 0s 12ms/step - loss: 0.8367
# 8/8 [==============================] - 0s 9ms/step - loss: 0.8368
# 8/8 [==============================] - 0s 11ms/step - loss: 0.8411
# 8/8 [==============================] - 0s 12ms/step - loss: 0.8368
# 8/8 [==============================] - 1s 11ms/step
# 8/8 [==============================] - 0s 16ms/step - loss: 0.8006
# 8/8 [==============================] - 0s 13ms/step - loss: 0.8117
# 8/8 [==============================] - 0s 15ms/step - loss: 0.8088
# 8/8 [==============================] - 1s 22ms/stepss: 0.7269
# 8/8 [==============================] - 0s 23ms/step - loss: 0.8429
# 8/8 [==============================] - 0s 21ms/step - loss: 0.8087
# 8/8 [==============================] - 0s 27ms/step - loss: 0.8010
# 8/8 [==============================] - 0s 19ms/step - loss: 0.8118
# 8/8 [==============================] - 1s 12ms/step
# 8/8 [==============================] - 1s 14ms/step
# 8/8 [==============================] - 1s 15ms/step
# 8/8 [==============================] - 1s 12ms/step
# 8/8 [==============================] - 1s 12ms/step
# 8/8 [==============================] - 1s 15ms/step
# 8/8 [==============================] - 1s 15ms/step
# 8/8 [==============================] - 1s 10ms/step
# 8/8 [==============================] - 1s 10ms/step
# 8/8 [==============================] - 1s 12ms/step
# 8/8 [==============================] - 1s 11ms/step
# 8/8 [==============================] - 1s 13ms/step
# 8/8 [==============================] - 0s 7ms/step - loss: 0.8256
# 8/8 [==============================] - 0s 4ms/step - loss: 0.7594
# 8/8 [==============================] - 0s 3ms/step
# 8/8 [==============================] - 0s 3ms/step
# 8/8 [==============================] - 0s 12ms/step - loss: 0.8142
# 8/8 [==============================] - 0s 25ms/step - loss: 0.7803
# 8/8 [==============================] - 0s 16ms/step - loss: 0.8186
# 8/8 [==============================] - 0s 16ms/step - loss: 0.8209
# 8/8 [==============================] - 0s 20ms/step - loss: 0.8309
# 8/8 [==============================] - 0s 20ms/step - loss: 0.7801
# 8/8 [==============================] - 0s 20ms/step - loss: 0.7856
# 8/8 [==============================] - 0s 23ms/step - loss: 0.8196
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7898
# 8/8 [==============================] - 0s 13ms/step - loss: 0.7986
# 8/8 [==============================] - 2s 3ms/step
# 8/8 [==============================] - 2s 6ms/step
# 8/8 [==============================] - 2s 6ms/step
# 8/8 [==============================] - 2s 6ms/step
# 8/8 [==============================] - 2s 11ms/step
# 8/8 [==============================] - 2s 9ms/step
# 8/8 [==============================] - 2s 6ms/step
# 8/8 [==============================] - 2s 6ms/step
# 8/8 [==============================] - 1s 4ms/step
# 8/8 [==============================] - 1s 2ms/step
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7829
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7359
# 8/8 [==============================] - 0s 6ms/step - loss: 0.7925
# 8/8 [==============================] - 0s 7ms/step - loss: 0.7674
# 8/8 [==============================] - 0s 7ms/step - loss: 0.7875
# 8/8 [==============================] - 0s 7ms/step - loss: 0.7423
# 8/8 [==============================] - 0s 7ms/step - loss: 0.7519
# 8/8 [==============================] - 0s 9ms/step - loss: 0.7541
# 8/8 [==============================] - 0s 6ms/step - loss: 0.7521
# 8/8 [==============================] - 2s 5ms/step
# 8/8 [==============================] - 2s 6ms/step
# 8/8 [==============================] - 2s 4ms/step
# 8/8 [==============================] - 2s 3ms/step
# 8/8 [==============================] - 2s 4ms/step
# 8/8 [==============================] - 2s 4ms/step
# 8/8 [==============================] - 2s 4ms/step
# 8/8 [==============================] - 2s 4ms/step
# 8/8 [==============================] - 2s 3ms/step
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7469
# 8/8 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s