# %%
# Importing necessary modules
import numpy as np
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.metrics import r2_score, mean_squared_error
from model_data_definitions import *
from concurrent.futures import ThreadPoolExecutor

# Function to generate cross validation dataset
def generate_cross_validation_dataset(data, num_folds):
    X, y = data.drop('target', axis=1).values, data['target'].values
    
    dataset_list = []
    kf = KFold(n_splits=num_folds)
    fold = 0

    # Splitting data into training and testing set for each fold in the cross-validation 
    for train_index, test_index in kf.split(X):
        fold += 1
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]
        
        dataset_list.append((X_train, y_train, X_test, y_test , fold))
    
    return dataset_list

# Function to train and evaluate model
def train_evaluate_model(model_tuple, fold_data, epoch_number):
    
    model, name = model_tuple
    X_train, y_train, X_test, y_test , fold = fold_data
    
    # Training the model 
    history = model.fit(X_train,
                        y_train,
                        epochs=epoch_number,
                        verbose=0,
                        validation_data=(X_test,y_test))

     # Evaluating the trained model on test data
    loss = model.evaluate(X_test, y_test, verbose=0)

    # Making predictions on the test data
    predictions = model.predict(X_test)
    
    # Calculate metrics 
    r_squared_value = r2_score(y_test,predictions)
    test_error = mean_squared_error(y_test,predictions)

    results = {
        'model': name,
        'fold': fold,
        'train_history': history.history['loss'],
        'val_history': history.history['val_loss'],
        'loss': loss,
        'r_squared_value': r_squared_value,
        'test_error': test_error}
    
    return results

# Function to evaluate models in parallel
def evaluate_models_parallel(fold_data, dataset_name):
    
    models = initialize_all_models(fold_data[0].shape[1], seed_val=fold_data[4])
    compile_models(models)

     # Training and evaluating all models in parallel using ThreadPoolExecutor 
    results = []
    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(train_evaluate_model, model, fold_data, 2): model for model in models}
        for future in futures:
            result = future.result()
            results.append(result)
    
    return results

# Function to evaluate all folds in parallel
def evaluate_all_folds_parallel(kfold_datasets, dataset_name):
    
     # Evaluating all folds in parallel using ThreadPoolExecutor 
    results = []
    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(evaluate_models_parallel, fold_data, dataset_name): fold_data for fold_data in kfold_datasets}
        for future in futures:
            result = future.result()
            results.extend(result)
    
    return results

# Fetching data and running evaluations
filtered_datasets_metadata, datasets = fetch_return_filtered_pmlb_data_sets()

num_folds = 4

list_of_kfold_datasets = []
for dataset, row in zip(datasets, filtered_datasets_metadata.iterrows()):
    dataset_name = row[1]['dataset']
    list_of_kfold_datasets.append(generate_cross_validation_dataset(dataset, num_folds))
    
evaluate_all_folds_parallel(list_of_kfold_datasets[0], '1029_LEV')
# Out:
# 4/4 [==============================] - 3s 320ms/step
# 4/4 [==============================] - 5s 204ms/step
# 3/4 [=====================>........] - ETA: 0sWARNING:tensorflow:5 out of the last 14 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001D157BE67A0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 4/4 [==============================] - ETA: 0sWARNING:tensorflow:5 out of the last 16 calls to <function Model.make_test_function.<locals>.test_function at 0x000001D0C6695B40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 4/4 [==============================] - 4s 321ms/step
# 4/4 [==============================] - ETA: 0sWARNING:tensorflow:6 out of the last 18 calls to <function Model.make_test_function.<locals>.test_function at 0x000001D1479B4430> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 4/4 [==============================] - 3s 331ms/step
# 4/4 [==============================] - 4s 227ms/step
# 4/4 [==============================] - 3s 323ms/step
# 4/4 [==============================] - 4s 468ms/step
# 4/4 [==============================] - 3s 506ms/step
# 4/4 [==============================] - 4s 505ms/step
# 4/4 [==============================] - 4s 543ms/step
# 1/4 [======>.......................] - ETA: 7sWARNING:tensorflow:5 out of the last 14 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001D13334F640> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 4/4 [==============================] - 4s 456ms/step
# 4/4 [==============================] - 4s 490ms/step
# 4/4 [==============================] - 4s 452ms/step
# 4/4 [==============================] - 4s 413ms/step
# 4/4 [==============================] - 3s 450ms/step
# 4/4 [==============================] - 4s 478ms/step
# 4/4 [==============================] - 4s 559ms/step
# 4/4 [==============================] - 5s 622ms/step
# 4/4 [==============================] - 5s 567ms/step
# 4/4 [==============================] - 5s 651ms/step
# 4/4 [==============================] - 5s 543ms/step
# 4/4 [==============================] - 5s 465ms/step
# 4/4 [==============================] - 6s 884ms/step
# 4/4 [==============================] - 6s 810ms/step
# 4/4 [==============================] - 7s 860ms/step
# 4/4 [==============================] - 6s 722ms/step
# 4/4 [==============================] - 6s 646ms/step
# 4/4 [==============================] - 5s 323ms/step
# 4/4 [==============================] - 6s 316ms/step
# 4/4 [==============================] - 5s 327ms/step
# 4/4 [==============================] - 5s 199ms/step
# 4/4 [==============================] - 5s 272ms/step
# 4/4 [==============================] - 6s 199ms/step
# 4/4 [==============================] - 5s 180ms/step
# 4/4 [==============================] - 5s 129ms/step
# 4/4 [==============================] - 5s 191ms/step
# 4/4 [==============================] - 6s 251ms/step
# 4/4 [==============================] - 4s 274ms/step
# 4/4 [==============================] - 6s 331ms/step
# 4/4 [==============================] - 4s 320ms/step
# 4/4 [==============================] - 5s 352ms/step
# 4/4 [==============================] - 5s 289ms/step
# 4/4 [==============================] - 4s 284ms/step
# 4/4 [==============================] - 5s 291ms/step
# 4/4 [==============================] - 5s 305ms/step
# 4/4 [==============================] - 4s 355ms/step
# 4/4 [==============================] - 4s 383ms/step
# 4/4 [==============================] - 4s 280ms/step
# 4/4 [==============================] - 4s 271ms/step
# 4/4 [==============================] - 4s 300ms/step
# 4/4 [==============================] - 4s 282ms/step
# 4/4 [==============================] - 4s 278ms/step
# 4/4 [==============================] - 4s 308ms/step
# 4/4 [==============================] - 3s 236ms/step
# 4/4 [==============================] - 4s 294ms/step
# 4/4 [==============================] - 4s 340ms/step
# 4/4 [==============================] - 3s 237ms/step
# 4/4 [==============================] - 4s 242ms/step
# 4/4 [==============================] - 3s 195ms/step
# 4/4 [==============================] - 3s 224ms/step
# 4/4 [==============================] - 3s 239ms/step
# 4/4 [==============================] - 4s 269ms/step
# 4/4 [==============================] - 4s 247ms/step
# 4/4 [==============================] - 4s 270ms/step
# 4/4 [==============================] - 3s 238ms/step
# 4/4 [==============================] - 3s 239ms/step
# 4/4 [==============================] - 3s 234ms/step
# 4/4 [==============================] - 3s 246ms/step
# 4/4 [==============================] - 3s 216ms/step
# 4/4 [==============================] - 3s 218ms/step
# 4/4 [==============================] - 3s 255ms/step
# 4/4 [==============================] - 3s 240ms/step
# 4/4 [==============================] - 3s 264ms/step
# 4/4 [==============================] - 3s 254ms/step
# 4/4 [==============================] - 3s 175ms/step
# 4/4 [==============================] - 3s 269ms/step
# 4/4 [==============================] - 2s 164ms/step
# 4/4 [==============================] - 3s 163ms/step
# 4/4 [==============================] - 3s 111ms/step
# 4/4 [==============================] - 2s 53ms/step
# 4/4 [==============================] - 3s 64ms/step
# 4/4 [==============================] - 2s 45ms/step
# 4/4 [==============================] - 2s 36ms/step
# 4/4 [==============================] - 3s 70ms/step
# 4/4 [==============================] - 3s 94ms/step
# 4/4 [==============================] - 2s 64ms/step
# 4/4 [==============================] - 3s 71ms/step
# 4/4 [==============================] - 3s 49ms/step
# 4/4 [==============================] - 3s 107ms/step
# 4/4 [==============================] - 4s 147ms/step
# 4/4 [==============================] - 15s 143ms/step
# 4/4 [==============================] - 15s 217ms/step
# 4/4 [==============================] - 14s 30ms/step
# 4/4 [==============================] - 14s 55ms/step
# 4/4 [==============================] - 14s 58ms/step
# 4/4 [==============================] - 13s 28ms/step
# 4/4 [==============================] - 11s 15ms/step
# 4/4 [==============================] - 11s 36ms/step
# 4/4 [==============================] - 13s 50ms/step
# 4/4 [==============================] - 12s 29ms/step
# 4/4 [==============================] - 11s 13ms/step
# 4/4 [==============================] - 11s 37ms/step
# 4/4 [==============================] - 11s 32ms/step
# 4/4 [==============================] - 12s 38ms/step
# 4/4 [==============================] - 10s 25ms/step
# 4/4 [==============================] - 12s 49ms/step
# 4/4 [==============================] - 12s 31ms/step
# 4/4 [==============================] - 12s 16ms/step
# 4/4 [==============================] - 11s 12ms/step
# 4/4 [==============================] - 12s 15ms/step
# 4/4 [==============================] - 12s 30ms/step
# 4/4 [==============================] - 11s 38ms/step
# 4/4 [==============================] - 11s 28ms/step
# 4/4 [==============================] - 11s 26ms/step
# 4/4 [==============================] - 10s 41ms/step
# 4/4 [==============================] - 10s 11ms/step
# 4/4 [==============================] - 10s 32ms/step
# 4/4 [==============================] - 11s 11ms/step
# 4/4 [==============================] - 11s 17ms/step
# 4/4 [==============================] - 9s 25ms/step
# 4/4 [==============================] - 10s 17ms/step
# 4/4 [==============================] - 10s 25ms/step
# 4/4 [==============================] - 9s 11ms/step
# 4/4 [==============================] - 11s 15ms/step
# 4/4 [==============================] - 9s 11ms/step
# 4/4 [==============================] - 10s 17ms/step
# 4/4 [==============================] - 9s 14ms/step
# 4/4 [==============================] - 9s 25ms/step
# 4/4 [==============================] - 7s 17ms/step
# 4/4 [==============================] - 9s 12ms/step
# 4/4 [==============================] - 8s 13ms/step
# 4/4 [==============================] - 8s 15ms/step
# 4/4 [==============================] - 7s 16ms/step
# 4/4 [==============================] - 8s 24ms/step
# 4/4 [==============================] - 8s 14ms/step
# 4/4 [==============================] - 7s 14ms/step
# 4/4 [==============================] - 7s 37ms/step
# 4/4 [==============================] - 7s 14ms/step
# 4/4 [==============================] - 4s 7ms/step
# 4/4 [==============================] - 2s 10ms/step
# 4/4 [==============================] - 11s 30ms/step
# 4/4 [==============================] - 12s 12ms/step
# 4/4 [==============================] - 12s 11ms/step
# 4/4 [==============================] - 12s 22ms/step
# 4/4 [==============================] - 12s 8ms/step
# 4/4 [==============================] - 12s 9ms/step
# 4/4 [==============================] - 11s 9ms/step
# 4/4 [==============================] - 12s 9ms/step
# 4/4 [==============================] - 12s 7ms/step
# 4/4 [==============================] - 12s 10ms/step
# 4/4 [==============================] - 11s 9ms/step
# 4/4 [==============================] - 10s 9ms/step
# 4/4 [==============================] - 10s 23ms/step
# 4/4 [==============================] - 10s 8ms/step
# 4/4 [==============================] - 10s 7ms/step
# 4/4 [==============================] - 10s 8ms/step
# 4/4 [==============================] - 10s 7ms/step
# 4/4 [==============================] - 9s 28ms/step
# 4/4 [==============================] - 9s 7ms/step
# 4/4 [==============================] - 9s 32ms/step
# 4/4 [==============================] - 9s 12ms/step
# 4/4 [==============================] - 9s 10ms/step
# 4/4 [==============================] - 9s 13ms/step
# 4/4 [==============================] - 9s 26ms/step
# 4/4 [==============================] - 9s 31ms/step
# 4/4 [==============================] - 9s 16ms/step
# 4/4 [==============================] - 9s 33ms/step
# 4/4 [==============================] - 8s 34ms/step
# 4/4 [==============================] - 8s 27ms/step
# 4/4 [==============================] - 8s 29ms/step
# 4/4 [==============================] - 9s 11ms/step
# 4/4 [==============================] - 8s 27ms/step
# 4/4 [==============================] - 8s 50ms/step
# 4/4 [==============================] - 8s 15ms/step
# 4/4 [==============================] - 8s 40ms/step
# 4/4 [==============================] - 9s 34ms/step
# 4/4 [==============================] - 8s 58ms/step
# 4/4 [==============================] - 8s 33ms/step
# 4/4 [==============================] - 8s 14ms/step
# 4/4 [==============================] - 9s 62ms/step
# 4/4 [==============================] - 8s 28ms/step
# 4/4 [==============================] - 8s 12ms/step
# 4/4 [==============================] - 8s 10ms/step
# 4/4 [==============================] - 8s 22ms/step
# 4/4 [==============================] - 8s 13ms/step
# 4/4 [==============================] - 8s 5ms/step
# 4/4 [==============================] - 8s 5ms/step
# 4/4 [==============================] - 6s 3ms/step
# 4/4 [==============================] - 9s 3ms/step
# 4/4 [==============================] - 1s 2ms/step
# [{'model': 'Linear Model',
#   'fold': 1,
#   'train_history': [1.9237008094787598, 1.8234695196151733],
#   'val_history': [2.005307674407959, 1.887061357498169],
#   'loss': 1.887061357498169,
#   'r_squared_value': -4.044631305747247,
#   'test_error': 5.18386312978587},
#  {'model': 'Wide ReLU ANN',
#   'fold': 1,
#   'train_history': [1.0195107460021973, 0.5012112855911255],
#   'val_history': [0.4753933846950531, 0.4933238923549652],
#   'loss': 0.4933238923549652,
#   'r_squared_value': 0.6282871426806469,
#   'test_error': 0.3819721321813671},
#  {'model': 'Deep ReLU ANN',
#   'fold': 1,
#   'train_history': [0.8225933909416199, 0.6690576076507568],
#   'val_history': [0.7233116030693054, 0.6547183394432068],
#   'loss': 0.6547183394432068,
#   'r_squared_value': 0.2931374201190522,
#   'test_error': 0.7263719870856618},
#  {'model': 'One Parameter',
#   'fold': 1,
#   'train_history': [2.7675464153289795, 2.7385470867156982],
#   'val_history': [2.7910003662109375, 2.762000799179077],
#   'loss': 2.762000799179077,
#   'r_squared_value': -7.423752554418501,
#   'test_error': 8.656248124920449},
#  {'model': 'Spline ANN (z=1)',
#   'fold': 1,
#   'train_history': [1.7651046514511108, 1.6768149137496948],
#   'val_history': [1.7549320459365845, 1.6674869060516357],
#   'loss': 1.6674869060516357,
#   'r_squared_value': -2.604807531765299,
#   'test_error': 3.70430021964202},
#  {'model': 'Lookup Table (z=1)',
#   'fold': 1,
#   'train_history': [2.7675464153289795, 2.7385470867156982],
#   'val_history': [2.7910003662109375, 2.762000799179077],
#   'loss': 2.762000799179077,
#   'r_squared_value': -7.423752554418501,
#   'test_error': 8.656248124920449},
#  {'model': 'ABEL-Spline (z=1)',
#   'fold': 1,
#   'train_history': [1.6192102432250977, 1.2719660997390747],
#   'val_history': [1.4727487564086914, 1.115687608718872],
#   'loss': 1.115687608718872,
#   'r_squared_value': -0.8736479596438631,
#   'test_error': 1.9253606433300332},
#  {'model': 'Spline ANN (z=2)',
#   'fold': 1,
#   'train_history': [1.7449707984924316, 1.658706784248352],
#   'val_history': [1.735459804534912, 1.6490646600723267],
#   'loss': 1.6490646600723267,
#   'r_squared_value': -2.531005054376789,
#   'test_error': 3.628460793877587},
#  {'model': 'Lookup Table (z=2)',
#   'fold': 1,
#   'train_history': [2.723499059677124, 2.695358991622925],
#   'val_history': [2.733553171157837, 2.7056996822357178],
#   'loss': 2.7056996822357178,
#   'r_squared_value': -7.316543016110426,
#   'test_error': 8.546079603355071},
#  {'model': 'ABEL-Spline (z=2)',
#   'fold': 1,
#   'train_history': [1.5929292440414429, 1.245000958442688],
#   'val_history': [1.441845417022705, 1.0863746404647827],
#   'loss': 1.0863746404647827,
#   'r_squared_value': -0.8204364446543586,
#   'test_error': 1.8706804905268184},
#  {'model': 'Spline ANN (z=4)',
#   'fold': 1,
#   'train_history': [1.7314927577972412, 1.6465318202972412],
#   'val_history': [1.7279130220413208, 1.6432324647903442],
#   'loss': 1.6432324647903442,
#   'r_squared_value': -2.4910891313848245,
#   'test_error': 3.5874431914110443},
#  {'model': 'Lookup Table (z=4)',
#   'fold': 1,
#   'train_history': [2.6134884357452393, 2.5875494480133057],
#   'val_history': [2.5821633338928223, 2.557284355163574],
#   'loss': 2.557284355163574,
#   'r_squared_value': -6.719578344262763,
#   'test_error': 7.932638706564412},
#  {'model': 'ABEL-Spline (z=4)',
#   'fold': 1,
#   'train_history': [1.607613444328308, 1.2658379077911377],
#   'val_history': [1.4580856561660767, 1.1136010885238647],
#   'loss': 1.1136010885238647,
#   'r_squared_value': -0.9163750824423227,
#   'test_error': 1.9692670347177301},
#  {'model': 'Spline ANN (z=8)',
#   'fold': 1,
#   'train_history': [1.73755943775177, 1.6510027647018433],
#   'val_history': [1.7276889085769653, 1.64288330078125],
#   'loss': 1.64288330078125,
#   'r_squared_value': -2.500194360292711,
#   'test_error': 3.596799724636788},
#  {'model': 'Lookup Table (z=8)',
#   'fold': 1,
#   'train_history': [2.572378635406494, 2.546739101409912],
#   'val_history': [2.5653915405273438, 2.540614366531372],
#   'loss': 2.540614366531372,
#   'r_squared_value': -6.639779867569151,
#   'test_error': 7.850637791914056},
#  {'model': 'ABEL-Spline (z=8)',
#   'fold': 1,
#   'train_history': [1.6124712228775024, 1.2755130529403687],
#   'val_history': [1.4643207788467407, 1.119044542312622],
#   'loss': 1.119044542312622,
#   'r_squared_value': -0.9124881990506888,
#   'test_error': 1.965272873344487},
#  {'model': 'Spline ANN (z=10)',
#   'fold': 1,
#   'train_history': [1.7448899745941162, 1.6601251363754272],
#   'val_history': [1.7365167140960693, 1.6530959606170654],
#   'loss': 1.6530959606170654,
#   'r_squared_value': -2.5410364261181324,
#   'test_error': 3.6387690314789918},
#  {'model': 'Lookup Table (z=10)',
#   'fold': 1,
#   'train_history': [2.570632219314575, 2.5451619625091553],
#   'val_history': [2.5671169757843018, 2.542593002319336],
#   'loss': 2.542593002319336,
#   'r_squared_value': -6.643682801877773,
#   'test_error': 7.854648447209597},
#  {'model': 'ABEL-Spline (z=10)',
#   'fold': 1,
#   'train_history': [1.6339420080184937, 1.2918295860290527],
#   'val_history': [1.4838260412216187, 1.1433019638061523],
#   'loss': 1.1433019638061523,
#   'r_squared_value': -0.9255826509080465,
#   'test_error': 1.978728732073108},
#  {'model': 'Linear Model',
#   'fold': 2,
#   'train_history': [3.8383803367614746, 3.4810631275177],
#   'val_history': [3.743436574935913, 3.4007298946380615],
#   'loss': 3.4007298946380615,
#   'r_squared_value': -16.579787742153183,
#   'test_error': 14.844372769474148},
#  {'model': 'Wide ReLU ANN',
#   'fold': 2,
#   'train_history': [1.050455093383789, 0.5070807337760925],
#   'val_history': [0.5476175546646118, 0.49278560280799866],
#   'loss': 0.49278560280799866,
#   'r_squared_value': 0.5278297705468957,
#   'test_error': 0.3987005417502013},
#  {'model': 'Deep ReLU ANN',
#   'fold': 2,
#   'train_history': [1.540887475013733, 0.6360530853271484],
#   'val_history': [0.8898556232452393, 0.4781270921230316],
#   'loss': 0.4781270921230316,
#   'r_squared_value': 0.5239127961170851,
#   'test_error': 0.40200803495873333},
#  {'model': 'One Parameter',
#   'fold': 2,
#   'train_history': [2.7853240966796875, 2.756324529647827],
#   'val_history': [2.631000280380249, 2.6020007133483887],
#   'loss': 2.6020007133483887,
#   'r_squared_value': -8.018010286555912,
#   'test_error': 7.614807885967812},
#  {'model': 'Spline ANN (z=1)',
#   'fold': 2,
#   'train_history': [1.7299033403396606, 1.6404399871826172],
#   'val_history': [1.5404229164123535, 1.451208233833313],
#   'loss': 1.451208233833313,
#   'r_squared_value': -2.354182133020497,
#   'test_error': 2.8322713931225074},
#  {'model': 'Lookup Table (z=1)',
#   'fold': 2,
#   'train_history': [2.7853240966796875, 2.7563247680664062],
#   'val_history': [2.631000280380249, 2.6020007133483887],
#   'loss': 2.6020007133483887,
#   'r_squared_value': -8.018010286555912,
#   'test_error': 7.614807885967812},
#  {'model': 'ABEL-Spline (z=1)',
#   'fold': 2,
#   'train_history': [1.6124916076660156, 1.2530200481414795],
#   'val_history': [1.2858411073684692, 0.9177670478820801],
#   'loss': 0.9177670478820801,
#   'r_squared_value': -0.6866272032533707,
#   'test_error': 1.4241880104271463},
#  {'model': 'Spline ANN (z=2)',
#   'fold': 2,
#   'train_history': [1.7501407861709595, 1.6624263525009155],
#   'val_history': [1.565015435218811, 1.477441430091858],
#   'loss': 1.477441430091858,
#   'r_squared_value': -2.4488903204906416,
#   'test_error': 2.9122429866222976},
#  {'model': 'Lookup Table (z=2)',
#   'fold': 2,
#   'train_history': [2.7433648109436035, 2.715552806854248],
#   'val_history': [2.540576219558716, 2.5139193534851074],
#   'loss': 2.5139193534851074,
#   'r_squared_value': -7.735570685928467,
#   'test_error': 7.376315887197998},
#  {'model': 'ABEL-Spline (z=2)',
#   'fold': 2,
#   'train_history': [1.6499745845794678, 1.2977784872055054],
#   'val_history': [1.316900372505188, 0.956417441368103],
#   'loss': 0.956417441368103,
#   'r_squared_value': -0.7850819623177856,
#   'test_error': 1.5073232089811381},
#  {'model': 'Spline ANN (z=4)',
#   'fold': 2,
#   'train_history': [1.7565230131149292, 1.670654535293579],
#   'val_history': [1.5749622583389282, 1.4899396896362305],
#   'loss': 1.4899396896362305,
#   'r_squared_value': -2.4901415319165263,
#   'test_error': 2.9470755095503147},
#  {'model': 'Lookup Table (z=4)',
#   'fold': 2,
#   'train_history': [2.631594181060791, 2.604901075363159],
#   'val_history': [2.4564599990844727, 2.4301207065582275],
#   'loss': 2.4301207065582275,
#   'r_squared_value': -7.3740059111828575,
#   'test_error': 7.071010591402805},
#  {'model': 'ABEL-Spline (z=4)',
#   'fold': 2,
#   'train_history': [1.6436389684677124, 1.2994818687438965],
#   'val_history': [1.3196693658828735, 0.9731513261795044],
#   'loss': 0.9731513261795044,
#   'r_squared_value': -0.744684976258086,
#   'test_error': 1.4732119939523278},
#  {'model': 'Spline ANN (z=8)',
#   'fold': 2,
#   'train_history': [1.7539143562316895, 1.667084813117981],
#   'val_history': [1.5658891201019287, 1.4804424047470093],
#   'loss': 1.4804424047470093,
#   'r_squared_value': -2.4634073044106293,
#   'test_error': 2.9245011278443354},
#  {'model': 'Lookup Table (z=8)',
#   'fold': 2,
#   'train_history': [2.5893306732177734, 2.563798666000366],
#   'val_history': [2.4172985553741455, 2.3924496173858643],
#   'loss': 2.3924496173858643,
#   'r_squared_value': -7.156439683467331,
#   'test_error': 6.887297668719814},
#  {'model': 'ABEL-Spline (z=8)',
#   'fold': 2,
#   'train_history': [1.683394193649292, 1.3403931856155396],
#   'val_history': [1.3570469617843628, 1.0168676376342773],
#   'loss': 1.0168676376342773,
#   'r_squared_value': -0.8975204192553172,
#   'test_error': 1.6022662420191898},
#  {'model': 'Spline ANN (z=10)',
#   'fold': 2,
#   'train_history': [1.7512454986572266, 1.6648430824279785],
#   'val_history': [1.5648170709609985, 1.4794732332229614],
#   'loss': 1.4794732332229614,
#   'r_squared_value': -2.4663497259380476,
#   'test_error': 2.926985708582087},
#  {'model': 'Lookup Table (z=10)',
#   'fold': 2,
#   'train_history': [2.5912747383117676, 2.5657734870910645],
#   'val_history': [2.4171106815338135, 2.3924546241760254],
#   'loss': 2.3924546241760254,
#   'r_squared_value': -7.154201922608436,
#   'test_error': 6.885408103450564},
#  {'model': 'ABEL-Spline (z=10)',
#   'fold': 2,
#   'train_history': [1.6565876007080078, 1.322156310081482],
#   'val_history': [1.33370041847229, 0.9958343505859375],
#   'loss': 0.9958343505859375,
#   'r_squared_value': -0.8325319526927131,
#   'test_error': 1.5473899808537268},
#  {'model': 'Linear Model',
#   'fold': 3,
#   'train_history': [3.3415231704711914, 3.193166732788086],
#   'val_history': [3.3209590911865234, 3.1690120697021484],
#   'loss': 3.1690120697021484,
#   'r_squared_value': -14.598217875123991,
#   'test_error': 16.0521260152901},
#  {'model': 'Wide ReLU ANN',
#   'fold': 3,
#   'train_history': [1.0872650146484375, 0.49996399879455566],
#   'val_history': [0.6036005616188049, 0.5992541313171387],
#   'loss': 0.5992541313171387,
#   'r_squared_value': 0.3009728715222266,
#   'test_error': 0.7193688179164766},
#  {'model': 'Deep ReLU ANN',
#   'fold': 3,
#   'train_history': [0.8708704113960266, 0.6027000546455383],
#   'val_history': [0.8127574324607849, 0.650688886642456],
#   'loss': 0.650688886642456,
#   'r_squared_value': 0.21875452277035579,
#   'test_error': 0.8039797206170269},
#  {'model': 'One Parameter',
#   'fold': 3,
#   'train_history': [2.7508797645568848, 2.7218804359436035],
#   'val_history': [2.941000461578369, 2.9120006561279297],
#   'loss': 2.9120006561279297,
#   'r_squared_value': -8.239965357048437,
#   'test_error': 9.508848348938546},
#  {'model': 'Spline ANN (z=1)',
#   'fold': 3,
#   'train_history': [1.707995891571045, 1.618725061416626],
#   'val_history': [1.8661870956420898, 1.7765929698944092],
#   'loss': 1.7765929698944092,
#   'r_squared_value': -2.942871390554012,
#   'test_error': 4.0576089480191335},
#  {'model': 'Lookup Table (z=1)',
#   'fold': 3,
#   'train_history': [2.7508797645568848, 2.7218801975250244],
#   'val_history': [2.941000461578369, 2.9120006561279297],
#   'loss': 2.9120006561279297,
#   'r_squared_value': -8.239965357048437,
#   'test_error': 9.508848348938546},
#  {'model': 'ABEL-Spline (z=1)',
#   'fold': 3,
#   'train_history': [1.6262600421905518, 1.2714673280715942],
#   'val_history': [1.6360338926315308, 1.2663806676864624],
#   'loss': 1.2663806676864624,
#   'r_squared_value': -1.252554437234433,
#   'test_error': 2.3181037713579546},
#  {'model': 'Spline ANN (z=2)',
#   'fold': 3,
#   'train_history': [1.731552004814148, 1.6448781490325928],
#   'val_history': [1.8898876905441284, 1.8028721809387207],
#   'loss': 1.8028721809387207,
#   'r_squared_value': -3.04648589367683,
#   'test_error': 4.164238633182825},
#  {'model': 'Lookup Table (z=2)',
#   'fold': 3,
#   'train_history': [2.701167345046997, 2.6730823516845703],
#   'val_history': [2.931506395339966, 2.9028067588806152],
#   'loss': 2.9028067588806152,
#   'r_squared_value': -8.232361313505457,
#   'test_error': 9.501023027728467},
#  {'model': 'ABEL-Spline (z=2)',
#   'fold': 3,
#   'train_history': [1.636496901512146, 1.2928396463394165],
#   'val_history': [1.6289149522781372, 1.2690939903259277],
#   'loss': 1.2690939903259277,
#   'r_squared_value': -1.248212971918146,
#   'test_error': 2.313635969400964},
#  {'model': 'Spline ANN (z=4)',
#   'fold': 3,
#   'train_history': [1.7161670923233032, 1.6307796239852905],
#   'val_history': [1.870482325553894, 1.7856183052062988],
#   'loss': 1.7856183052062988,
#   'r_squared_value': -2.9707842242522986,
#   'test_error': 4.08633404517804},
#  {'model': 'Lookup Table (z=4)',
#   'fold': 3,
#   'train_history': [2.5874555110931396, 2.5618858337402344],
#   'val_history': [2.8207790851593018, 2.794459819793701],
#   'loss': 2.794459819793701,
#   'r_squared_value': -7.660036032815052,
#   'test_error': 8.912043081369971},
#  {'model': 'ABEL-Spline (z=4)',
#   'fold': 3,
#   'train_history': [1.6057307720184326, 1.2605538368225098],
#   'val_history': [1.6075851917266846, 1.2528431415557861],
#   'loss': 1.2528431415557861,
#   'r_squared_value': -1.2248088447761805,
#   'test_error': 2.2895507821591674},
#  {'model': 'Spline ANN (z=8)',
#   'fold': 3,
#   'train_history': [1.7062910795211792, 1.6215745210647583],
#   'val_history': [1.8637690544128418, 1.776986837387085],
#   'loss': 1.776986837387085,
#   'r_squared_value': -2.94657779454104,
#   'test_error': 4.061423208362184},
#  {'model': 'Lookup Table (z=8)',
#   'fold': 3,
#   'train_history': [2.5500051975250244, 2.5243070125579834],
#   'val_history': [2.7625794410705566, 2.737039804458618],
#   'loss': 2.737039804458618,
#   'r_squared_value': -7.382450646108893,
#   'test_error': 8.626379959910661},
#  {'model': 'ABEL-Spline (z=8)',
#   'fold': 3,
#   'train_history': [1.613512635231018, 1.2705647945404053],
#   'val_history': [1.6246562004089355, 1.2684189081192017],
#   'loss': 1.2684189081192017,
#   'r_squared_value': -1.2607567701449214,
#   'test_error': 2.326544792156138},
#  {'model': 'Spline ANN (z=10)',
#   'fold': 3,
#   'train_history': [1.7179138660430908, 1.6329033374786377],
#   'val_history': [1.8804047107696533, 1.7948509454727173],
#   'loss': 1.7948509454727173,
#   'r_squared_value': -3.012426577209726,
#   'test_error': 4.129188190606529},
#  {'model': 'Lookup Table (z=10)',
#   'fold': 3,
#   'train_history': [2.5510005950927734, 2.525449514389038],
#   'val_history': [2.7668726444244385, 2.7410149574279785],
#   'loss': 2.7410149574279785,
#   'r_squared_value': -7.398954275631006,
#   'test_error': 8.643363845051868},
#  {'model': 'ABEL-Spline (z=10)',
#   'fold': 3,
#   'train_history': [1.5980192422866821, 1.253775954246521],
#   'val_history': [1.6051124334335327, 1.2513633966445923],
#   'loss': 1.2513633966445923,
#   'r_squared_value': -1.2166058402891693,
#   'test_error': 2.2811090702415844},
#  {'model': 'Linear Model',
#   'fold': 4,
#   'train_history': [2.560638189315796, 2.4223134517669678],
#   'val_history': [2.582289218902588, 2.4446544647216797],
#   'loss': 2.4446544647216797,
#   'r_squared_value': -9.341238498898166,
#   'test_error': 9.450857864143035},
#  {'model': 'Wide ReLU ANN',
#   'fold': 4,
#   'train_history': [1.1109709739685059, 0.5162144899368286],
#   'val_history': [0.45495712757110596, 0.4751136898994446],
#   'loss': 0.4751136898994446,
#   'r_squared_value': 0.58735594741875,
#   'test_error': 0.3771153996540045},
#  {'model': 'Deep ReLU ANN',
#   'fold': 4,
#   'train_history': [0.6820888519287109, 0.5267899632453918],
#   'val_history': [0.5099233388900757, 0.451782763004303],
#   'loss': 0.451782763004303,
#   'r_squared_value': 0.6223470324460908,
#   'test_error': 0.3451370470475177},
#  {'model': 'One Parameter',
#   'fold': 4,
#   'train_history': [2.7819907665252686, 2.7529914379119873],
#   'val_history': [2.6610002517700195, 2.632000684738159],
#   'loss': 2.632000684738159,
#   'r_squared_value': -7.580072142216249,
#   'test_error': 7.841327930771431},
#  {'model': 'Spline ANN (z=1)',
#   'fold': 4,
#   'train_history': [1.740264892578125, 1.650423288345337],
#   'val_history': [1.6014010906219482, 1.5228577852249146],
#   'loss': 1.5228577852249146,
#   'r_squared_value': -2.3228812403303314,
#   'test_error': 3.0367811655378905},
#  {'model': 'Lookup Table (z=1)',
#   'fold': 4,
#   'train_history': [2.7819907665252686, 2.752990961074829],
#   'val_history': [2.6610002517700195, 2.632000684738159],
#   'loss': 2.632000684738159,
#   'r_squared_value': -7.580072142216249,
#   'test_error': 7.841327930771431},
#  {'model': 'ABEL-Spline (z=1)',
#   'fold': 4,
#   'train_history': [1.6669280529022217, 1.3129056692123413],
#   'val_history': [1.4121215343475342, 1.0977078676223755],
#   'loss': 1.0977078676223755,
#   'r_squared_value': -0.8214912808617159,
#   'test_error': 1.6646608815795225},
#  {'model': 'Spline ANN (z=2)',
#   'fold': 4,
#   'train_history': [1.7419795989990234, 1.6537901163101196],
#   'val_history': [1.6038928031921387, 1.527279257774353],
#   'loss': 1.527279257774353,
#   'r_squared_value': -2.3494033820471594,
#   'test_error': 3.0610197508528993},
#  {'model': 'Lookup Table (z=2)',
#   'fold': 4,
#   'train_history': [2.7367634773254395, 2.7087173461914062],
#   'val_history': [2.613424777984619, 2.585514783859253],
#   'loss': 2.585514783859253,
#   'r_squared_value': -7.512501302307079,
#   'test_error': 7.779574940178442},
#  {'model': 'ABEL-Spline (z=2)',
#   'fold': 4,
#   'train_history': [1.6905969381332397, 1.3426769971847534],
#   'val_history': [1.4344743490219116, 1.1359565258026123],
#   'loss': 1.1359565258026123,
#   'r_squared_value': -0.9539781006856611,
#   'test_error': 1.785740586216626},
#  {'model': 'Spline ANN (z=4)',
#   'fold': 4,
#   'train_history': [1.7522677183151245, 1.6662517786026],
#   'val_history': [1.6100878715515137, 1.5347485542297363],
#   'loss': 1.5347485542297363,
#   'r_squared_value': -2.385765280032106,
#   'test_error': 3.094250889421342},
#  {'model': 'Lookup Table (z=4)',
#   'fold': 4,
#   'train_history': [2.623673677444458, 2.5975422859191895],
#   'val_history': [2.5049686431884766, 2.4797370433807373],
#   'loss': 2.4797370433807373,
#   'r_squared_value': -7.147048350915965,
#   'test_error': 7.445587487902101},
#  {'model': 'ABEL-Spline (z=4)',
#   'fold': 4,
#   'train_history': [1.646040439605713, 1.305269718170166],
#   'val_history': [1.3858439922332764, 1.0832834243774414],
#   'loss': 1.0832834243774414,
#   'r_squared_value': -0.7631430673029933,
#   'test_error': 1.6113364492082058},
#  {'model': 'Spline ANN (z=8)',
#   'fold': 4,
#   'train_history': [1.7528057098388672, 1.6668082475662231],
#   'val_history': [1.6093342304229736, 1.5346788167953491],
#   'loss': 1.5346788167953491,
#   'r_squared_value': -2.3831057852170674,
#   'test_error': 3.0918203771098787},
#  {'model': 'Lookup Table (z=8)',
#   'fold': 4,
#   'train_history': [2.5817923545837402, 2.5565025806427],
#   'val_history': [2.466970920562744, 2.44199538230896],
#   'loss': 2.44199538230896,
#   'r_squared_value': -7.023269296750621,
#   'test_error': 7.332465810300394},
#  {'model': 'ABEL-Spline (z=8)',
#   'fold': 4,
#   'train_history': [1.6586008071899414, 1.3151413202285767],
#   'val_history': [1.4048959016799927, 1.1038681268692017],
#   'loss': 1.1038681268692017,
#   'r_squared_value': -0.8288745697307074,
#   'test_error': 1.6714084692768938},
#  {'model': 'Spline ANN (z=10)',
#   'fold': 4,
#   'train_history': [1.7308382987976074, 1.643285870552063],
#   'val_history': [1.596341609954834, 1.5197933912277222],
#   'loss': 1.5197933912277222,
#   'r_squared_value': -2.297407425578314,
#   'test_error': 3.0135006462360217},
#  {'model': 'Lookup Table (z=10)',
#   'fold': 4,
#   'train_history': [2.5839197635650635, 2.5582263469696045],
#   'val_history': [2.4661002159118652, 2.440969944000244],
#   'loss': 2.440969944000244,
#   'r_squared_value': -7.022246851572072,
#   'test_error': 7.331531397651719},
#  {'model': 'ABEL-Spline (z=10)',
#   'fold': 4,
#   'train_history': [1.643896460533142, 1.2989062070846558],
#   'val_history': [1.3995013236999512, 1.0989868640899658],
#   'loss': 1.0989868640899658,
#   'r_squared_value': -0.8078721688421231,
#   'test_error': 1.6522143751048164},
#  {'model': 'Linear Model',
#   'fold': 5,
#   'train_history': [3.666740655899048, 3.5676932334899902],
#   'val_history': [3.7277181148529053, 3.6282835006713867],
#   'loss': 3.6282835006713867,
#   'r_squared_value': -25.40763944315652,
#   'test_error': 19.9932238224138},
#  {'model': 'Wide ReLU ANN',
#   'fold': 5,
#   'train_history': [1.1158772706985474, 0.5237415432929993],
#   'val_history': [0.5733522772789001, 0.47035008668899536],
#   'loss': 0.47035008668899536,
#   'r_squared_value': 0.49735366449123164,
#   'test_error': 0.38055354061368846},
#  {'model': 'Deep ReLU ANN',
#   'fold': 5,
#   'train_history': [0.7235393524169922, 0.5397735238075256],
#   'val_history': [0.5502450466156006, 0.4962889850139618],
#   'loss': 0.4962889850139618,
#   'r_squared_value': 0.4558147121880941,
#   'test_error': 0.41200268140239393},
#  {'model': 'One Parameter',
#   'fold': 5,
#   'train_history': [2.773102045059204, 2.744102716445923],
#   'val_history': [2.7410004138946533, 2.712000846862793],
#   'loss': 2.712000846862793,
#   'r_squared_value': -9.714632215358275,
#   'test_error': 8.112048050247749},
#  {'model': 'Spline ANN (z=1)',
#   'fold': 5,
#   'train_history': [1.7473913431167603, 1.6595308780670166],
#   'val_history': [1.6783552169799805, 1.5835380554199219],
#   'loss': 1.5835380554199219,
#   'r_squared_value': -3.208911920986152,
#   'test_error': 3.186567215378615},
#  {'model': 'Lookup Table (z=1)',
#   'fold': 5,
#   'train_history': [2.773102045059204, 2.7441024780273438],
#   'val_history': [2.7410004138946533, 2.712000846862793],
#   'loss': 2.712000846862793,
#   'r_squared_value': -9.714632215358275,
#   'test_error': 8.112048050247749},
#  {'model': 'ABEL-Spline (z=1)',
#   'fold': 5,
#   'train_history': [1.6607450246810913, 1.3142800331115723],
#   'val_history': [1.4324077367782593, 1.0501155853271484],
#   'loss': 1.0501155853271484,
#   'r_squared_value': -1.16731226266415,
#   'test_error': 1.6408721140630278},
#  {'model': 'Spline ANN (z=2)',
#   'fold': 5,
#   'train_history': [1.740129828453064, 1.6536189317703247],
#   'val_history': [1.6645160913467407, 1.5718525648117065],
#   'loss': 1.5718525648117065,
#   'r_squared_value': -3.1526398907990965,
#   'test_error': 3.143963661323996},
#  {'model': 'Lookup Table (z=2)',
#   'fold': 5,
#   'train_history': [2.7231571674346924, 2.6954524517059326],
#   'val_history': [2.721608877182007, 2.693298101425171],
#   'loss': 2.693298101425171,
#   'r_squared_value': -9.665215579134802,
#   'test_error': 8.074634714962958},
#  {'model': 'ABEL-Spline (z=2)',
#   'fold': 5,
#   'train_history': [1.6618949174880981, 1.3164150714874268],
#   'val_history': [1.4310358762741089, 1.0526927709579468],
#   'loss': 1.0526927709579468,
#   'r_squared_value': -1.2035776995599416,
#   'test_error': 1.6683286763368317},
#  {'model': 'Spline ANN (z=4)',
#   'fold': 5,
#   'train_history': [1.7194256782531738, 1.6353572607040405],
#   'val_history': [1.6462706327438354, 1.5549288988113403],
#   'loss': 1.5549288988113403,
#   'r_squared_value': -3.091133360338424,
#   'test_error': 3.0973970671122206},
#  {'model': 'Lookup Table (z=4)',
#   'fold': 5,
#   'train_history': [2.609694004058838, 2.5838394165039062],
#   'val_history': [2.6427533626556396, 2.6154189109802246],
#   'loss': 2.6154189109802246,
#   'r_squared_value': -9.23998126377383,
#   'test_error': 7.7526898148031655},
#  {'model': 'ABEL-Spline (z=4)',
#   'fold': 5,
#   'train_history': [1.665529727935791, 1.3234013319015503],
#   'val_history': [1.4296215772628784, 1.0548772811889648],
#   'loss': 1.0548772811889648,
#   'r_squared_value': -1.2127895617589068,
#   'test_error': 1.6753029772076684},
#  {'model': 'Spline ANN (z=8)',
#   'fold': 5,
#   'train_history': [1.7410557270050049, 1.6561095714569092],
#   'val_history': [1.6655353307724, 1.57318115234375],
#   'loss': 1.57318115234375,
#   'r_squared_value': -3.174442530788732,
#   'test_error': 3.1604704400601484},
#  {'model': 'Lookup Table (z=8)',
#   'fold': 5,
#   'train_history': [2.5682458877563477, 2.5429999828338623],
#   'val_history': [2.604534387588501, 2.5781896114349365],
#   'loss': 2.5781896114349365,
#   'r_squared_value': -8.943610769244296,
#   'test_error': 7.528307713394856},
#  {'model': 'ABEL-Spline (z=8)',
#   'fold': 5,
#   'train_history': [1.6719269752502441, 1.3297157287597656],
#   'val_history': [1.436325192451477, 1.0666333436965942],
#   'loss': 1.0666333436965942,
#   'r_squared_value': -1.2841867560676645,
#   'test_error': 1.7293577930188286},
#  {'model': 'Spline ANN (z=10)',
#   'fold': 5,
#   'train_history': [1.7333035469055176, 1.6505589485168457],
#   'val_history': [1.6676713228225708, 1.5787850618362427],
#   'loss': 1.5787850618362427,
#   'r_squared_value': -3.1698703850132333,
#   'test_error': 3.1570088684935187},
#  {'model': 'Lookup Table (z=10)',
#   'fold': 5,
#   'train_history': [2.56667423248291, 2.5410256385803223],
#   'val_history': [2.604477882385254, 2.577906847000122],
#   'loss': 2.577906847000122,
#   'r_squared_value': -8.939600211299393,
#   'test_error': 7.52527131997477},
#  {'model': 'ABEL-Spline (z=10)',
#   'fold': 5,
#   'train_history': [1.60221529006958, 1.2617628574371338],
#   'val_history': [1.3737109899520874, 0.9997760653495789],
#   'loss': 0.9997760653495789,
#   'r_squared_value': -1.0370498271359692,
#   'test_error': 1.542250424124642},
#  {'model': 'Linear Model',
#   'fold': 6,
#   'train_history': [3.002413034439087, 2.8160839080810547],
#   'val_history': [3.2344846725463867, 3.036930799484253],
#   'loss': 3.036930799484253,
#   'r_squared_value': -15.368375388644122,
#   'test_error': 15.207857573589253},
#  {'model': 'Wide ReLU ANN',
#   'fold': 6,
#   'train_history': [1.2458813190460205, 0.5018258094787598],
#   'val_history': [0.5578413605690002, 0.55103600025177],
#   'loss': 0.55103600025177,
#   'r_squared_value': 0.47063471271026436,
#   'test_error': 0.49183328842089336},
#  {'model': 'Deep ReLU ANN',
#   'fold': 6,
#   'train_history': [1.0687261819839478, 0.5669559836387634],
#   'val_history': [0.6188635230064392, 0.5330560207366943],
#   'loss': 0.5330560207366943,
#   'r_squared_value': 0.48960187771041097,
#   'test_error': 0.4742108954192571},
#  {'model': 'One Parameter',
#   'fold': 6,
#   'train_history': [2.7508797645568848, 2.7218804359436035],
#   'val_history': [2.940999984741211, 2.9120006561279297],
#   'loss': 2.9120006561279297,
#   'r_squared_value': -9.126841404518938,
#   'test_error': 9.408848348938545},
#  {'model': 'Spline ANN (z=1)',
#   'fold': 6,
#   'train_history': [1.70956552028656, 1.620869517326355],
#   'val_history': [1.8657220602035522, 1.7738406658172607],
#   'loss': 1.7738406658172607,
#   'r_squared_value': -3.2497257639179216,
#   'test_error': 3.9484202072561407},
#  {'model': 'Lookup Table (z=1)',
#   'fold': 6,
#   'train_history': [2.7508797645568848, 2.7218804359436035],
#   'val_history': [2.940999984741211, 2.9120006561279297],
#   'loss': 2.9120006561279297,
#   'r_squared_value': -9.126841404518938,
#   'test_error': 9.408848348938545},
#  {'model': 'ABEL-Spline (z=1)',
#   'fold': 6,
#   'train_history': [1.640291690826416, 1.2844687700271606],
#   'val_history': [1.6575572490692139, 1.2837895154953003],
#   'loss': 1.2837895154953003,
#   'r_squared_value': -1.45842777007197,
#   'test_error': 2.2841252411738675},
#  {'model': 'Spline ANN (z=2)',
#   'fold': 6,
#   'train_history': [1.7360968589782715, 1.6487821340560913],
#   'val_history': [1.893242359161377, 1.8049805164337158],
#   'loss': 1.8049805164337158,
#   'r_squared_value': -3.3870496634588996,
#   'test_error': 4.0760078423196635},
#  {'model': 'Lookup Table (z=2)',
#   'fold': 6,
#   'train_history': [2.7029340267181396, 2.674949884414673],
#   'val_history': [2.911597967147827, 2.8834457397460938],
#   'loss': 2.8834457397460938,
#   'r_squared_value': -9.056881685113089,
#   'test_error': 9.343848773638571},
#  {'model': 'ABEL-Spline (z=2)',
#   'fold': 6,
#   'train_history': [1.615574598312378, 1.2667219638824463],
#   'val_history': [1.6310075521469116, 1.2675468921661377],
#   'loss': 1.2675468921661377,
#   'r_squared_value': -1.3958884518719357,
#   'test_error': 2.2260199606342157},
#  {'model': 'Spline ANN (z=4)',
#   'fold': 6,
#   'train_history': [1.7082891464233398, 1.6235696077346802],
#   'val_history': [1.8636996746063232, 1.7764593362808228],
#   'loss': 1.7764593362808228,
#   'r_squared_value': -3.2463315856651516,
#   'test_error': 3.9452666762414923},
#  {'model': 'Lookup Table (z=4)',
#   'fold': 6,
#   'train_history': [2.5901689529418945, 2.5637805461883545],
#   'val_history': [2.8139865398406982, 2.7879483699798584],
#   'loss': 2.7879483699798584,
#   'r_squared_value': -8.692275535346297,
#   'test_error': 9.005093199890245},
#  {'model': 'ABEL-Spline (z=4)',
#   'fold': 6,
#   'train_history': [1.580102801322937, 1.2402020692825317],
#   'val_history': [1.5967819690704346, 1.24069082736969],
#   'loss': 1.24069082736969,
#   'r_squared_value': -1.296363457881708,
#   'test_error': 2.1335512887178947},
#  {'model': 'Spline ANN (z=8)',
#   'fold': 6,
#   'train_history': [1.7156469821929932, 1.631131649017334],
#   'val_history': [1.869455099105835, 1.7826979160308838],
#   'loss': 1.7826979160308838,
#   'r_squared_value': -3.2956822449411023,
#   'test_error': 3.991118373774778},
#  {'model': 'Lookup Table (z=8)',
#   'fold': 6,
#   'train_history': [2.5488970279693604, 2.523505210876465],
#   'val_history': [2.785989284515381, 2.759948968887329],
#   'loss': 2.759948968887329,
#   'r_squared_value': -8.556075613932872,
#   'test_error': 8.878549852905032},
#  {'model': 'ABEL-Spline (z=8)',
#   'fold': 6,
#   'train_history': [1.5806301832199097, 1.244888186454773],
#   'val_history': [1.594590187072754, 1.244419813156128],
#   'loss': 1.244419813156128,
#   'r_squared_value': -1.3519932575457476,
#   'test_error': 2.1852369355857544},
#  {'model': 'Spline ANN (z=10)',
#   'fold': 6,
#   'train_history': [1.7199586629867554, 1.6351308822631836],
#   'val_history': [1.8764179944992065, 1.789239525794983],
#   'loss': 1.789239525794983,
#   'r_squared_value': -3.298317499131638,
#   'test_error': 3.993566788443205},
#  {'model': 'Lookup Table (z=10)',
#   'fold': 6,
#   'train_history': [2.5474555492401123, 2.522282123565674],
#   'val_history': [2.7846839427948, 2.7590978145599365],
#   'loss': 2.7590978145599365,
#   'r_squared_value': -8.559464945452497,
#   'test_error': 8.881698880819915},
#  {'model': 'ABEL-Spline (z=10)',
#   'fold': 6,
#   'train_history': [1.6580232381820679, 1.329266905784607],
#   'val_history': [1.677109956741333, 1.3326945304870605],
#   'loss': 1.3326945304870605,
#   'r_squared_value': -1.5915788477626553,
#   'test_error': 2.407835907456283},
#  {'model': 'Linear Model',
#   'fold': 7,
#   'train_history': [2.9908268451690674, 2.876100540161133],
#   'val_history': [3.2939460277557373, 3.194620132446289],
#   'loss': 3.194620132446289,
#   'r_squared_value': -18.71276402443512,
#   'test_error': 14.703750685826158},
#  {'model': 'Wide ReLU ANN',
#   'fold': 7,
#   'train_history': [1.1354855298995972, 0.5246948599815369],
#   'val_history': [0.5120919942855835, 0.4861108064651489],
#   'loss': 0.4861108064651489,
#   'r_squared_value': 0.44962658311526915,
#   'test_error': 0.41052353165432076},
#  {'model': 'Deep ReLU ANN',
#   'fold': 7,
#   'train_history': [1.6848344802856445, 0.8790569305419922],
#   'val_history': [1.3331897258758545, 0.549736499786377],
#   'loss': 0.549736499786377,
#   'r_squared_value': 0.3725756158467878,
#   'test_error': 0.46799584813988104},
#  {'model': 'One Parameter',
#   'fold': 7,
#   'train_history': [2.779768705368042, 2.7507693767547607],
#   'val_history': [2.6810004711151123, 2.652000665664673],
#   'loss': 2.652000665664673,
#   'r_squared_value': -9.429022604424869,
#   'test_error': 7.77900796064051},
#  {'model': 'Spline ANN (z=1)',
#   'fold': 7,
#   'train_history': [1.7503682374954224, 1.6609365940093994],
#   'val_history': [1.6244794130325317, 1.5372525453567505],
#   'loss': 1.5372525453567505,
#   'r_squared_value': -2.9742330183796746,
#   'test_error': 2.9643804084093994},
#  {'model': 'Lookup Table (z=1)',
#   'fold': 7,
#   'train_history': [2.779768705368042, 2.7507691383361816],
#   'val_history': [2.6810004711151123, 2.652000665664673],
#   'loss': 2.652000665664673,
#   'r_squared_value': -9.429022604424869,
#   'test_error': 7.77900796064051},
#  {'model': 'ABEL-Spline (z=1)',
#   'fold': 7,
#   'train_history': [1.6464226245880127, 1.2883566617965698],
#   'val_history': [1.3825180530548096, 1.0313471555709839],
#   'loss': 1.0313471555709839,
#   'r_squared_value': -0.978184593630615,
#   'test_error': 1.475527888389076},
#  {'model': 'Spline ANN (z=2)',
#   'fold': 7,
#   'train_history': [1.737038493156433, 1.649948239326477],
#   'val_history': [1.6080158948898315, 1.5226610898971558],
#   'loss': 1.5226610898971558,
#   'r_squared_value': -2.9391911402479356,
#   'test_error': 2.938242671510935},
#  {'model': 'Lookup Table (z=2)',
#   'fold': 7,
#   'train_history': [2.7348976135253906, 2.7069666385650635],
#   'val_history': [2.622330665588379, 2.5951035022735596],
#   'loss': 2.5951035022735596,
#   'r_squared_value': -9.201718753937193,
#   'test_error': 7.609462018561754},
#  {'model': 'ABEL-Spline (z=2)',
#   'fold': 7,
#   'train_history': [1.6587364673614502, 1.3120510578155518],
#   'val_history': [1.3960224390029907, 1.0567208528518677],
#   'loss': 1.0567208528518677,
#   'r_squared_value': -1.0817775941610859,
#   'test_error': 1.552797907484754},
#  {'model': 'Spline ANN (z=4)',
#   'fold': 7,
#   'train_history': [1.7531077861785889, 1.6673489809036255],
#   'val_history': [1.6300233602523804, 1.5473171472549438],
#   'loss': 1.5473171472549438,
#   'r_squared_value': -3.0379324439780486,
#   'test_error': 3.0118938099632264},
#  {'model': 'Lookup Table (z=4)',
#   'fold': 7,
#   'train_history': [2.630340337753296, 2.603745698928833],
#   'val_history': [2.468954563140869, 2.443490505218506],
#   'loss': 2.443490505218506,
#   'r_squared_value': -8.501914319106017,
#   'test_error': 7.087477890621178},
#  {'model': 'ABEL-Spline (z=4)',
#   'fold': 7,
#   'train_history': [1.645241379737854, 1.2995342016220093],
#   'val_history': [1.3825280666351318, 1.038535714149475],
#   'loss': 1.038535714149475,
#   'r_squared_value': -1.0483474895533416,
#   'test_error': 1.5278623924578374},
#  {'model': 'Spline ANN (z=8)',
#   'fold': 7,
#   'train_history': [1.72684907913208, 1.640291690826416],
#   'val_history': [1.6019917726516724, 1.5181328058242798],
#   'loss': 1.5181328058242798,
#   'r_squared_value': -2.8933790690470325,
#   'test_error': 2.9040714476021816},
#  {'model': 'Lookup Table (z=8)',
#   'fold': 7,
#   'train_history': [2.593405246734619, 2.567617893218994],
#   'val_history': [2.387603282928467, 2.3647005558013916],
#   'loss': 2.3647005558013916,
#   'r_squared_value': -8.001481472734193,
#   'test_error': 6.714205030512435},
#  {'model': 'ABEL-Spline (z=8)',
#   'fold': 7,
#   'train_history': [1.6159882545471191, 1.272560954093933],
# ...
#   'fold': 7,
#   'train_history': [2.592041492462158, 2.566391944885254],
#   'val_history': [2.389629602432251, 2.366767168045044],
#   'loss': 2.366767168045044,
#   'r_squared_value': -8.018182772929256,
#   'test_error': 6.726662530327932},
#  {'model': 'ABEL-Spline (z=10)',
#   'fold': 7,
#   'train_history': [1.6621209383010864, 1.3144630193710327],
#   'val_history': [1.3888957500457764, 1.0469192266464233],
#   'loss': 1.0469192266464233,
#   'r_squared_value': -1.0277228484191077,
#   'test_error': 1.5124784726358127},
#  {'model': 'Linear Model',
#   'fold': 8,
#   'train_history': [3.989985704421997, 3.6333305835723877],
#   'val_history': [3.7612578868865967, 3.419144868850708],
#   'loss': 3.419144868850708,
#   'r_squared_value': -15.389862441619293,
#   'test_error': 15.306492534228262},
#  {'model': 'Wide ReLU ANN',
#   'fold': 8,
#   'train_history': [1.1983907222747803, 0.5184604525566101],
#   'val_history': [0.5685353875160217, 0.4885956943035126],
#   'loss': 0.4885956943035126,
#   'r_squared_value': 0.61153689948125,
#   'test_error': 0.3627856895744606},
#  {'model': 'Deep ReLU ANN',
#   'fold': 8,
#   'train_history': [1.707293152809143, 0.8923152089118958],
#   'val_history': [1.4856650829315186, 0.5456945300102234],
#   'loss': 0.5456945300102234,
#   'r_squared_value': 0.5259858845556783,
#   'test_error': 0.44268178241345213},
#  {'model': 'One Parameter',
#   'fold': 8,
#   'train_history': [2.7686574459075928, 2.7396578788757324],
#   'val_history': [2.7810001373291016, 2.7520008087158203],
#   'loss': 2.7520008087158203,
#   'r_squared_value': -8.10954932004059,
#   'test_error': 8.507408109985908},
#  {'model': 'Spline ANN (z=1)',
#   'fold': 8,
#   'train_history': [1.7450062036514282, 1.6561081409454346],
#   'val_history': [1.720189094543457, 1.6323641538619995],
#   'loss': 1.6323641538619995,
#   'r_squared_value': -2.719508453335529,
#   'test_error': 3.473648944570051},
#  {'model': 'Lookup Table (z=1)',
#   'fold': 8,
#   'train_history': [2.7686574459075928, 2.7396578788757324],
#   'val_history': [2.7810001373291016, 2.7520008087158203],
#   'loss': 2.7520008087158203,
#   'r_squared_value': -8.10954932004059,
#   'test_error': 8.507408109985908},
#  {'model': 'ABEL-Spline (z=1)',
#   'fold': 8,
#   'train_history': [1.5751718282699585, 1.2191667556762695],
#   'val_history': [1.3995988368988037, 1.0408549308776855],
#   'loss': 1.0408549308776855,
#   'r_squared_value': -0.7805627446281629,
#   'test_error': 1.6628675472082415},
#  {'model': 'Spline ANN (z=2)',
#   'fold': 8,
#   'train_history': [1.7407383918762207, 1.6543174982070923],
#   'val_history': [1.7204623222351074, 1.6341469287872314],
#   'loss': 1.6341469287872314,
#   'r_squared_value': -2.738610892608905,
#   'test_error': 3.491488712607457},
#  {'model': 'Lookup Table (z=2)',
#   'fold': 8,
#   'train_history': [2.7255189418792725, 2.697416067123413],
#   'val_history': [2.713441848754883, 2.6856894493103027],
#   'loss': 2.6856894493103027,
#   'r_squared_value': -7.8795756636420045,
#   'test_error': 8.29263571227527},
#  {'model': 'ABEL-Spline (z=2)',
#   'fold': 8,
#   'train_history': [1.5610196590423584, 1.2057198286056519],
#   'val_history': [1.3909180164337158, 1.0362142324447632],
#   'loss': 1.0362142324447632,
#   'r_squared_value': -0.8025641844601505,
#   'test_error': 1.683414691867335},
#  {'model': 'Spline ANN (z=4)',
#   'fold': 8,
#   'train_history': [1.7415391206741333, 1.655637264251709],
#   'val_history': [1.72368586063385, 1.6373376846313477],
#   'loss': 1.6373376846313477,
#   'r_squared_value': -2.7474319121139272,
#   'test_error': 3.499726662723197},
#  {'model': 'Lookup Table (z=4)',
#   'fold': 8,
#   'train_history': [2.6135213375091553, 2.58740496635437],
#   'val_history': [2.5840163230895996, 2.559243679046631],
#   'loss': 2.559243679046631,
#   'r_squared_value': -7.437933837179784,
#   'test_error': 7.880186410542201},
#  {'model': 'ABEL-Spline (z=4)',
#   'fold': 8,
#   'train_history': [1.6104778051376343, 1.2662922143936157],
#   'val_history': [1.4464843273162842, 1.0932981967926025],
#   'loss': 1.0932981967926025,
#   'r_squared_value': -0.9096614656192419,
#   'test_error': 1.7834328427418102},
#  {'model': 'Spline ANN (z=8)',
#   'fold': 8,
#   'train_history': [1.747745394706726, 1.6625492572784424],
#   'val_history': [1.730271816253662, 1.6459158658981323],
#   'loss': 1.6459158658981323,
#   'r_squared_value': -2.789532074461615,
#   'test_error': 3.539044004339703},
#  {'model': 'Lookup Table (z=8)',
#   'fold': 8,
#   'train_history': [2.5765860080718994, 2.5509533882141113],
#   'val_history': [2.53763484954834, 2.5133631229400635],
#   'loss': 2.5133631229400635,
#   'r_squared_value': -7.0925052536968884,
#   'test_error': 7.557590656427526},
#  {'model': 'ABEL-Spline (z=8)',
#   'fold': 8,
#   'train_history': [1.6003363132476807, 1.2545324563980103],
#   'val_history': [1.441792607307434, 1.097531795501709],
#   'loss': 1.097531795501709,
#   'r_squared_value': -0.9261178050029553,
#   'test_error': 1.7988014180922602},
#  {'model': 'Spline ANN (z=10)',
#   'fold': 8,
#   'train_history': [1.7337137460708618, 1.6495168209075928],
#   'val_history': [1.7106902599334717, 1.625564694404602],
#   'loss': 1.625564694404602,
#   'r_squared_value': -2.693909696013436,
#   'test_error': 3.4497422651069485},
#  {'model': 'Lookup Table (z=10)',
#   'fold': 8,
#   'train_history': [2.5745770931243896, 2.549145460128784],
#   'val_history': [2.5351061820983887, 2.510869264602661],
#   'loss': 2.510869264602661,
#   'r_squared_value': -7.07979512354423,
#   'test_error': 7.545720665877958},
#  {'model': 'ABEL-Spline (z=10)',
#   'fold': 8,
#   'train_history': [1.6310077905654907, 1.2801529169082642],
#   'val_history': [1.471968412399292, 1.1201708316802979],
#   'loss': 1.1201708316802979,
#   'r_squared_value': -1.004520100170978,
#   'test_error': 1.8720213215496768},
#  {'model': 'Linear Model',
#   'fold': 9,
#   'train_history': [3.2085249423980713, 3.0335493087768555],
#   'val_history': [2.7410922050476074, 2.6254992485046387],
#   'loss': 2.6254992485046387,
#   'r_squared_value': -12.868550225846722,
#   'test_error': 11.033818559683652},
#  {'model': 'Wide ReLU ANN',
#   'fold': 9,
#   'train_history': [1.2314985990524292, 0.5266097187995911],
#   'val_history': [0.49494361877441406, 0.39465847611427307],
#   'loss': 0.39465847611427307,
#   'r_squared_value': 0.6890411954468334,
#   'test_error': 0.2473988249024994},
#  {'model': 'Deep ReLU ANN',
#   'fold': 9,
#   'train_history': [1.1732696294784546, 0.5814249515533447],
#   'val_history': [0.6409317255020142, 0.47444701194763184],
#   'loss': 0.47444701194763184,
#   'r_squared_value': 0.5741965059042553,
#   'test_error': 0.33876925990257445},
#  {'model': 'One Parameter',
#   'fold': 9,
#   'train_history': [2.789768695831299, 2.7607691287994385],
#   'val_history': [2.5910003185272217, 2.5620007514953613],
#   'loss': 2.5620007514953613,
#   'r_squared_value': -8.250185804712986,
#   'test_error': 7.359447826229652},
#  {'model': 'Spline ANN (z=1)',
#   'fold': 9,
#   'train_history': [1.7744779586791992, 1.6857047080993652],
#   'val_history': [1.5547653436660767, 1.4708340167999268],
#   'loss': 1.4708340167999268,
#   'r_squared_value': -2.567921709457957,
#   'test_error': 2.8386385120447506},
#  {'model': 'Lookup Table (z=1)',
#   'fold': 9,
#   'train_history': [2.789768695831299, 2.7607691287994385],
#   'val_history': [2.5910003185272217, 2.5620007514953613],
#   'loss': 2.5620007514953613,
#   'r_squared_value': -8.250185804712986,
#   'test_error': 7.359447826229652},
#  {'model': 'ABEL-Spline (z=1)',
#   'fold': 9,
#   'train_history': [1.664159893989563, 1.3081399202346802],
#   'val_history': [1.3060873746871948, 0.9641693830490112],
#   'loss': 0.9641693830490112,
#   'r_squared_value': -0.7636030718620097,
#   'test_error': 1.403122603973415},
#  {'model': 'Spline ANN (z=2)',
#   'fold': 9,
#   'train_history': [1.7843055725097656, 1.6955782175064087],
#   'val_history': [1.5517301559448242, 1.4713435173034668],
#   'loss': 1.4713435173034668,
#   'r_squared_value': -2.58644879720217,
#   'test_error': 2.8533786630540465},
#  {'model': 'Lookup Table (z=2)',
#   'fold': 9,
#   'train_history': [2.747565746307373, 2.7193899154663086],
#   'val_history': [2.513068199157715, 2.485873222351074],
#   'loss': 2.485873222351074,
#   'r_squared_value': -8.016675598937065,
#   'test_error': 7.173667106514329},
#  {'model': 'ABEL-Spline (z=2)',
#   'fold': 9,
#   'train_history': [1.6676448583602905, 1.3191739320755005],
#   'val_history': [1.3123116493225098, 0.9765278100967407],
#   'loss': 0.9765278100967407,
#   'r_squared_value': -0.7701137101775977,
#   'test_error': 1.4083024678172966},
#  {'model': 'Spline ANN (z=4)',
#   'fold': 9,
#   'train_history': [1.7725070714950562, 1.6862096786499023],
#   'val_history': [1.5449525117874146, 1.4641871452331543],
#   'loss': 1.4641871452331543,
#   'r_squared_value': -2.5359450660839333,
#   'test_error': 2.8131978945763776},
#  {'model': 'Lookup Table (z=4)',
#   'fold': 9,
#   'train_history': [2.6362340450286865, 2.610137701034546],
#   'val_history': [2.397477865219116, 2.3726065158843994],
#   'loss': 2.3726065158843994,
#   'r_squared_value': -7.5487455867749365,
#   'test_error': 6.8013819888381395},
#  {'model': 'ABEL-Spline (z=4)',
#   'fold': 9,
#   'train_history': [1.6199404001235962, 1.2832632064819336],
#   'val_history': [1.2665477991104126, 0.940687894821167],
#   'loss': 0.940687894821167,
#   'r_squared_value': -0.6916720683838973,
#   'test_error': 1.3458942976062287},
#  {'model': 'Spline ANN (z=8)',
#   'fold': 9,
#   'train_history': [1.7605739831924438, 1.6748697757720947],
#   'val_history': [1.5381065607070923, 1.4578477144241333],
#   'loss': 1.4578477144241333,
#   'r_squared_value': -2.5064391464757017,
#   'test_error': 2.7897229849360685},
#  {'model': 'Lookup Table (z=8)',
#   'fold': 9,
#   'train_history': [2.595557928085327, 2.569894552230835],
#   'val_history': [2.3670690059661865, 2.3421542644500732],
#   'loss': 2.3421542644500732,
#   'r_squared_value': -7.345121418884837,
#   'test_error': 6.639378600864776},
#  {'model': 'ABEL-Spline (z=8)',
#   'fold': 9,
#   'train_history': [1.6179448366165161, 1.2720857858657837],
#   'val_history': [1.2660373449325562, 0.9347984194755554],
#   'loss': 0.9347984194755554,
#   'r_squared_value': -0.6788703822668738,
#   'test_error': 1.335709276131525},
#  {'model': 'Spline ANN (z=10)',
#   'fold': 9,
#   'train_history': [1.7795071601867676, 1.693252682685852],
#   'val_history': [1.5580947399139404, 1.4763225317001343],
#   'loss': 1.4763225317001343,
#   'r_squared_value': -2.58660586295227,
#   'test_error': 2.8535036245648264},
#  {'model': 'Lookup Table (z=10)',
#   'fold': 9,
#   'train_history': [2.5962154865264893, 2.5701818466186523],
#   'val_history': [2.3678324222564697, 2.3430016040802],
#   'loss': 2.3430016040802,
#   'r_squared_value': -7.3441400065525055,
#   'test_error': 6.638597789213174},
#  {'model': 'ABEL-Spline (z=10)',
#   'fold': 9,
#   'train_history': [1.6277164220809937, 1.2818158864974976],
#   'val_history': [1.2804954051971436, 0.9469318389892578],
#   'loss': 0.9469318389892578,
#   'r_squared_value': -0.7438974046397908,
#   'test_error': 1.3874447751314176},
#  {'model': 'Linear Model',
#   'fold': 10,
#   'train_history': [5.227171897888184, 4.9682416915893555],
#   'val_history': [5.888691425323486, 5.583632946014404],
#   'loss': 5.583632946014404,
#   'r_squared_value': -43.76398201620147,
#   'test_error': 44.8132223964193},
#  {'model': 'Wide ReLU ANN',
#   'fold': 10,
#   'train_history': [1.1003539562225342, 0.4945056140422821],
#   'val_history': [0.5960804224014282, 0.5632660984992981],
#   'loss': 0.5632660984992981,
#   'r_squared_value': 0.46299807897389866,
#   'test_error': 0.5375926231392302},
#  {'model': 'Deep ReLU ANN',
#   'fold': 10,
#   'train_history': [1.541749358177185, 0.7789084911346436],
#   'val_history': [1.2488278150558472, 0.6115192770957947],
#   'loss': 0.6115192770957947,
#   'r_squared_value': 0.36093103005425,
#   'test_error': 0.6397719458126905},
#  {'model': 'One Parameter',
#   'fold': 10,
#   'train_history': [2.766435384750366, 2.737436056137085],
#   'val_history': [2.8010003566741943, 2.772000789642334],
#   'loss': 2.772000789642334,
#   'r_squared_value': -7.675545040310645,
#   'test_error': 8.685088139854988},
#  {'model': 'Spline ANN (z=1)',
#   'fold': 10,
#   'train_history': [1.7648825645446777, 1.6758273839950562],
#   'val_history': [1.7657872438430786, 1.6797715425491333],
#   'loss': 1.6797715425491333,
#   'r_squared_value': -2.6963137266488633,
#   'test_error': 3.700379671748178},
#  {'model': 'Lookup Table (z=1)',
#   'fold': 10,
#   'train_history': [2.766435384750366, 2.737436056137085],
#   'val_history': [2.8010003566741943, 2.772000789642334],
#   'loss': 2.772000789642334,
#   'r_squared_value': -7.675545040310645,
#   'test_error': 8.685088139854988},
#  {'model': 'ABEL-Spline (z=1)',
#   'fold': 10,
#   'train_history': [1.6387231349945068, 1.2825546264648438],
#   'val_history': [1.4921706914901733, 1.1345744132995605],
#   'loss': 1.1345744132995605,
#   'r_squared_value': -0.9575595556413097,
#   'test_error': 1.9597128711525154},
#  {'model': 'Spline ANN (z=2)',
#   'fold': 10,
#   'train_history': [1.7304507493972778, 1.6435011625289917],
#   'val_history': [1.7379037141799927, 1.6532756090164185],
#   'loss': 1.6532756090164185,
#   'r_squared_value': -2.6008626066489606,
#   'test_error': 3.604823555516275},
#  {'model': 'Lookup Table (z=2)',
#   'fold': 10,
#   'train_history': [2.7169506549835205, 2.6886649131774902],
#   'val_history': [2.8010952472686768, 2.772181510925293],
#   'loss': 2.772181510925293,
#   'r_squared_value': -7.676544240564345,
#   'test_error': 8.686088439228968},
#  {'model': 'ABEL-Spline (z=2)',
#   'fold': 10,
#   'train_history': [1.624921441078186, 1.2803810834884644],
#   'val_history': [1.4948530197143555, 1.1569466590881348],
#   'loss': 1.1569466590881348,
#   'r_squared_value': -1.0349100844544457,
#   'test_error': 2.037148485547346},
#  {'model': 'Spline ANN (z=4)',
#   'fold': 10,
#   'train_history': [1.7485765218734741, 1.6634249687194824],
#   'val_history': [1.7495843172073364, 1.6668663024902344],
#   'loss': 1.6668663024902344,
#   'r_squared_value': -2.6588132480921147,
#   'test_error': 3.662837942665017},
#  {'model': 'Lookup Table (z=4)',
#   'fold': 10,
#   'train_history': [2.6007566452026367, 2.5746943950653076],
#   'val_history': [2.7241523265838623, 2.696474313735962],
#   'loss': 2.696474313735962,
#   'r_squared_value': -7.397381483287312,
#   'test_error': 8.406618602918929},
#  {'model': 'ABEL-Spline (z=4)',
#   'fold': 10,
#   'train_history': [1.6438562870025635, 1.2988852262496948],
#   'val_history': [1.5034153461456299, 1.1564605236053467],
#   'loss': 1.1564605236053467,
#   'r_squared_value': -1.0121169806114882,
#   'test_error': 2.0143303092901608},
#  {'model': 'Spline ANN (z=8)',
#   'fold': 10,
#   'train_history': [1.7501251697540283, 1.6668012142181396],
#   'val_history': [1.749907374382019, 1.6681729555130005],
#   'loss': 1.6681729555130005,
#   'r_squared_value': -2.6708832148995385,
#   'test_error': 3.6749211864359284},
#  {'model': 'Lookup Table (z=8)',
#   'fold': 10,
#   'train_history': [2.5551583766937256, 2.5297274589538574],
#   'val_history': [2.7021448612213135, 2.6753499507904053],
#   'loss': 2.6753499507904053,
#   'r_squared_value': -7.259609762447839,
#   'test_error': 8.268695333186534},
#  {'model': 'ABEL-Spline (z=8)',
#   'fold': 10,
#   'train_history': [1.6423141956329346, 1.2989001274108887],
#   'val_history': [1.5092005729675293, 1.171984076499939],
#   'loss': 1.171984076499939,
#   'r_squared_value': -1.049139683793237,
#   'test_error': 2.05139373744541},
#  {'model': 'Spline ANN (z=10)',
#   'fold': 10,
#   'train_history': [1.7392207384109497, 1.6532033681869507],
#   'val_history': [1.7456263303756714, 1.6637449264526367],
#   'loss': 1.6637449264526367,
#   'r_squared_value': -2.654091394731033,
#   'test_error': 3.6581108952652373},
#  {'model': 'Lookup Table (z=10)',
#   'fold': 10,
#   'train_history': [2.5597891807556152, 2.5338327884674072],
#   'val_history': [2.704794406890869, 2.6772208213806152],
#   'loss': 2.6772208213806152,
#   'r_squared_value': -7.263336481753488,
#   'test_error': 8.272426151883417},
#  {'model': 'ABEL-Spline (z=10)',
#   'fold': 10,
#   'train_history': [1.593530297279358, 1.2562580108642578],
#   'val_history': [1.4515835046768188, 1.1147671937942505],
#   'loss': 1.1147671937942505,
#   'r_squared_value': -0.8901406417047806,
#   'test_error': 1.8922197964106562}]

# %%
# Importing necessary modules
import os
import numpy as np
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.metrics import r2_score, mean_squared_error
from model_data_definitions import *
from concurrent.futures import ThreadPoolExecutor

# Function to generate cross validation dataset
def generate_cross_validation_dataset(data, num_folds):
    X, y = data.drop('target', axis=1).values, data['target'].values
    
    dataset_list = []
    kf = KFold(n_splits=num_folds)
    fold = 0

    # Splitting data into training and testing set for each fold in the cross-validation 
    for train_index, test_index in kf.split(X):
        fold += 1
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]
        
        dataset_list.append((X_train, y_train, X_test, y_test , fold))
    
    return dataset_list

# Function to train and evaluate model
def train_evaluate_model(model_tuple, fold_data, epoch_number, dataset_name):
    
    model, name = model_tuple
    X_train, y_train, X_test, y_test , fold = fold_data
    
    # Training the model 
    history = model.fit(X_train,
                        y_train,
                        epochs=epoch_number,
                        verbose=0,
                        validation_data=(X_test,y_test))

     # Evaluating the trained model on test data
    loss = model.evaluate(X_test, y_test, verbose=0)

    # Making predictions on the test data
    predictions = model.predict(X_test)
    
    # Calculate metrics 
    r_squared_value = r2_score(y_test,predictions)
    test_error = mean_squared_error(y_test,predictions)

    results = {
        'model': name,
        'fold': fold,
        'train_history': history.history['loss'],
        'val_history': history.history['val_loss'],
        'loss': loss,
        'r_squared_value': r_squared_value,
        'test_error': test_error}

    # Save results to numpy file
    if not os.path.exists('aggregate_results'):
        os.makedirs('aggregate_results')

    np.save(f'aggregate_results/{dataset_name}-{name}-fold{fold}.npy', results)

# Function to evaluate models in parallel
def evaluate_models_parallel(fold_data, dataset_name):
    
    models = initialize_all_models(fold_data[0].shape[1], seed_val=fold_data[4])
    compile_models(models)

     # Training and evaluating all models in parallel using ThreadPoolExecutor 
    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(train_evaluate_model, model, fold_data, 2, dataset_name): model for model in models}
        for future in futures:
            future.result()  # Just to make sure all tasks are finished

# Function to evaluate all folds in parallel
def evaluate_all_folds_parallel(kfold_datasets, dataset_name):
    
     # Evaluating all folds in parallel using ThreadPoolExecutor 
    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(evaluate_models_parallel, fold_data, dataset_name): fold_data for fold_data in kfold_datasets}
        for future in futures:
            future.result()  # Just to make sure all tasks are finished

# Fetching data and running evaluations
filtered_datasets_metadata, datasets = fetch_return_filtered_pmlb_data_sets()

num_folds = 4

list_of_kfold_datasets = []
for dataset, row in zip(datasets, filtered_datasets_metadata.iterrows()):
    dataset_name = row[1]['dataset']
    list_of_kfold_datasets.append(generate_cross_validation_dataset(dataset, num_folds))
    
evaluate_all_folds_parallel(list_of_kfold_datasets[0], '1029_LEV')
# Out:
# 8/8 [==============================] - 1s 37ms/step
# 8/8 [==============================] - 1s 20ms/step
# 8/8 [==============================] - 1s 75ms/step
# 8/8 [==============================] - 1s 85ms/step
# 8/8 [==============================] - 1s 32ms/step
# 8/8 [==============================] - 2s 46ms/step
# 8/8 [==============================] - 2s 76ms/step
# 8/8 [==============================] - 2s 50ms/step
# 8/8 [==============================] - 2s 76ms/step
# 8/8 [==============================] - 2s 47ms/step
# 8/8 [==============================] - 2s 29ms/step
# 8/8 [==============================] - 2s 29ms/step
# 8/8 [==============================] - 2s 67ms/step
# 8/8 [==============================] - 2s 76ms/step
# 8/8 [==============================] - 2s 75ms/step
# 8/8 [==============================] - 2s 60ms/step
# 8/8 [==============================] - 2s 69ms/step
# 8/8 [==============================] - 2s 73ms/step
# 8/8 [==============================] - 1s 58ms/step
# 8/8 [==============================] - 2s 81ms/step
# 8/8 [==============================] - 2s 98ms/step
# 8/8 [==============================] - 2s 111ms/step
# 8/8 [==============================] - 2s 100ms/step
# 8/8 [==============================] - 2s 127ms/step
# 8/8 [==============================] - 2s 87ms/step
# 8/8 [==============================] - 2s 99ms/step
# 8/8 [==============================] - 2s 111ms/step
# 8/8 [==============================] - 2s 97ms/step
# 8/8 [==============================] - 1s 65ms/step
# 8/8 [==============================] - 2s 91ms/step
# 8/8 [==============================] - 1s 40ms/step
# 8/8 [==============================] - 1s 6ms/step
# 8/8 [==============================] - 1s 7ms/step
# 8/8 [==============================] - 1s 7ms/step
# 8/8 [==============================] - 1s 6ms/step
# 8/8 [==============================] - 5s 6ms/step
# 8/8 [==============================] - 5s 11ms/step
# 8/8 [==============================] - 5s 14ms/step
# 8/8 [==============================] - 5s 7ms/step
# 8/8 [==============================] - 4s 9ms/step
# 8/8 [==============================] - 5s 15ms/step
# 8/8 [==============================] - 4s 7ms/step
# 8/8 [==============================] - 4s 6ms/step
# 8/8 [==============================] - 4s 15ms/step
# 8/8 [==============================] - 4s 14ms/step
# 8/8 [==============================] - 4s 11ms/step
# 8/8 [==============================] - 4s 12ms/step
# 8/8 [==============================] - 4s 6ms/step
# 8/8 [==============================] - 4s 8ms/step
# 8/8 [==============================] - 3s 7ms/step
# 8/8 [==============================] - 4s 13ms/step
# 8/8 [==============================] - 3s 11ms/step
# 8/8 [==============================] - 4s 11ms/step
# 8/8 [==============================] - 4s 7ms/step
# 8/8 [==============================] - 3s 5ms/step
# 8/8 [==============================] - 5s 4ms/step
# 8/8 [==============================] - 4s 6ms/step
# 8/8 [==============================] - 4s 3ms/step
# 8/8 [==============================] - 3s 6ms/step
# 8/8 [==============================] - 3s 5ms/step
# 8/8 [==============================] - 4s 14ms/step
# 8/8 [==============================] - 4s 14ms/step
# 8/8 [==============================] - 3s 14ms/step
# 8/8 [==============================] - 3s 18ms/step
# 8/8 [==============================] - 3s 15ms/step
# 8/8 [==============================] - 3s 15ms/step
# 8/8 [==============================] - 4s 14ms/step
# 8/8 [==============================] - 4s 14ms/step
# 8/8 [==============================] - 4s 11ms/step
# 8/8 [==============================] - 4s 14ms/step
# 8/8 [==============================] - 4s 13ms/step
# 8/8 [==============================] - 4s 14ms/step
# 8/8 [==============================] - 3s 10ms/step
# 8/8 [==============================] - 3s 9ms/step
# 8/8 [==============================] - 3s 7ms/step
# 8/8 [==============================] - 0s 4ms/step
